# %% [markdown]
# # Lecture 3: Stream processing with Spark
#
# _Spark Structured Streaming_ is an extension of the Spark API that enables scalable stream processing.
#
# It's a well-documented API [link](https://spark.apache.org/docs/latest/structured-streaming-programming-guide.html#structured-streaming-programming-guide), which is however different from Spark Streaming, which has recently become deprecated since Spark version 3.4.0 (~last year)
#
# The main difference between Spark `Streaming` and `Structured Streaming` is that the former is based on the low-level RDD API, while the latter is based on DataFrames.
#
# Both APIs have however been designed to help with the continuous processing of streaming applications.
#
# The continuous stream of input data can be ingested from many data sources such as **Kafka**, **Amazon S3**, or **TCP sockets**.
#
# Processed data can be exported to an external database and used to make live dashboards or offline analyses, stored in files, or used in a further stage of a Kafka pipeline.
#
# Overall, the practice of reading data from a set of sources, pre-processing it, and then storing it in a different format for later analysis is extremely common and has its own name: **real-time ETL pipelines**.
# - **E**xtract
# - **T**ransform
# - **L**oad

# %% [markdown]
# ## Structured Streaming
#
# The key idea of this stream processing model is to treat the continuous stream as a table that is continuously appended to.
#
# This allows users to view the continuously incoming data as a DataFrame with new records being new rows to be included. It further expresses stream processing as a standard batch-like query on a static table, similar to what we have done in the Spark DataFrame lecture.
#
# ![](imgs/lecture3/structured-streaming-stream-as-a-table.png)
#
# Internally, the stream is divided into micro-batches produced by a "trigger," which could represent any given condition (e.g., every 1 second):
#
# - The input stream is a table (DataFrame) or the new rows to be appended to the previous DataFrame.
# - Every operation/query will produce a result table (DataFrame).
# - When the output table is updated, it can be written somewhere thanks to an output module/type.
#
# ![](imgs/lecture3/structured-streaming-model.png)
#
# **NB:** Although the input table can be viewed as an always-growing DataFrame, **Spark does not actually materialize the entire table**.
#
# - Only the latest data are processed (latest batch) and then discarded.
# - Conversely, the result table can be updated to keep track of the results from previous batches.
#
# There are three output modes:
#
# - ***Complete Mode*** where the entire output table is written to the Sink.
# - ***Append Mode*** where only the new rows appended in the Result Table since the last trigger will be processed by the Sink.
# - ***Update Mode*** where only the rows that were updated in the result table since the last trigger will be written to the Sink.
#
# In this notebook, the *Update Mode* and *Console* output sink will be used.
#
# - Results (i.e., only the updated records) will be displayed on the screen (i.e., on the "terminal").
# - However, the Sink could be a database, a file, Kafka, or more, depending on the needs and applications.

# %% [markdown]
# ## Create and Start a Spark Session

# %%
# import the python libraries to create/connect to a Spark Session
from pyspark.sql import SparkSession

# build a SparkSession 
#   connect to the master node on the port where the master node is listening (7077)
#   declare the app name 
#   configure the executor memory to 512 MB
#   either *connect* or *create* a new Spark Context
spark = SparkSession.builder \
    .master("spark://spark-master:7077")\
    .appName("My streaming spark application")\
    .config("spark.executor.memory", "512m")\
    .config("spark.sql.execution.arrow.pyspark.enabled", "true")\
    .config("spark.sql.execution.arrow.pyspark.fallback.enabled", "false")\
    .config("spark.sql.streaming.forceDeleteTempCheckpointLocation", "true")\
    .config("spark.sql.adaptive.enabled", "false")\
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/15 07:06:11 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://fe987d356028:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://spark-master:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>My streaming spark application</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### TCP Socket Source
#
# For this example, Spark will read data from a TCP socket using Spark Structured Streaming.
#
# A TCP socket is a communication endpoint used to establish a connection between two devices over a network. You can think of it as a telephone connection: two endpoints have to establish a connection; once the connection is established, communication can occur, with data transfer; as soon as one of the two ends interrupts the connection, the whole communication is lost.
#
# We will generate a dummy data stream representing fake credit card transactions.
#
# A simple Python program will be used to create this data stream. You will be able to find it in `utils/producer.py`. When executed, the producer will try to establish a TCP connection and send data on port `5555` of a given `host` (`spark-master` in our case).
#
# Before executing the producer program, take a moment to review the `producer.py` code to understand how it works. It's important to understand the logic of the program before using it to generate the streaming data.

# %%
! cat utils/producer.py
# Out:
# import socket
# import json
# import time
# import random
# import argparse
#
# # Define some lists of first and last names to use for generating random messages
# first_names=('John','Andy','Joe','Alice','Jill')
# last_names=('Johnson','Smith','Jones', 'Millers','Darby')
#
# # Define a function for sending messages over the socket
# def send_messages(client_socket):
#     try:
#         while 1:
#             # Generate a random message with a random name, surname, amount, delta_t, and flag
#             msg = {
#                 'name': random.choice(first_names),
#                 'surname': random.choice(last_names),
#                 'amount': float('{:.2f}'.format(random.random()*1000)),
#                 'delta_t': float('{:.2f}'.format(random.random()*10)),
#                 'flag': int(random.choices([0,1], weights=[0.8, 0.2])[0])
#             }
#             try:
#               # Encode the message as JSON and send it over the socket
#               client_socket.send((json.dumps(msg)+"\n").encode('utf-8'))
#               # Sleep for a short amount of time to avoid overwhelming the network
#               time.sleep(0.2)
#             except socket.error:
#               exit()
#
#     except KeyboardInterrupt:
#         # If the user presses Ctrl+C, exit gracefully
#         exit()
#
# if __name__ == "__main__":
#
#     # Parse command-line arguments to determine the hostname to use
#     parser = argparse.ArgumentParser()
#     parser.add_argument('--hostname', type=str, required=True)
#     args = parser.parse_args()
#     print('Using hostname:', args.hostname)
#
#     # Create a new socket and bind it to the specified hostname and port
#     new_skt = socket.socket()
#     host = args.hostname
#     port = 5555
#     new_skt.bind((host, port))
#     print("Now listening on port: %s" % str(port))
#
#     # Wait for a client to connect to the socket
#     new_skt.listen(5) #  waiting for client connection.
#     c, addr = new_skt.accept()
#     print("Received request from: " + str(addr))
#     # connection established, send messaged
#     send_messages(c)

# %% [markdown]
# The producer will generate new records in the form of a random combination of:
# - `name`
# - `surname`
# - `amount`: amount of the credit card transaction
# - `delta_t`: time between transactions
# - `flag`: random flag to indicate if potentially fraudulent or not
#
# This information will be formatted into a `.json` data format

# %% [markdown]
# ### Creating the streaming DataFrame from a TCP socket source
#
# To inform Spark that the data source will be a TCP socket located at a specific `hostname` and `port`, we can use the options `host` and `port` methods.
# * When declaring this source a message appears, warning that the TCP source is only meant for testing purposes.
#
# Refer to the [documentation](https://spark.apache.org/docs/latest/api/python/reference/pyspark.ss/api/pyspark.sql.streaming.DataStreamReader.html) for additional available options.
#
# Notice that the syntax is equivalent to the one used for example to read a set of files from a disk.

# %%
# the hostname and port number
hostname = "spark-master"
portnumber = 5555

rawMessagesDf = (
    spark
    .readStream
    .format("socket")
    .option("host", hostname)
    .option("port", portnumber)
    .load()
)                           #this declares that we have a STREAMING dataframe
# Out:
# 25/05/15 07:12:57 WARN TextSocketSourceProvider: The socket source should not be used for production applications! It does not support recovery.

# %% [markdown]
# ### Start the python producer.py script
#
# From a terminal/WSL, connect to the `spark-master` Docker container using the command
# ```bash
# docker exec -it spark-master bash
# ```
#
# From inside the docker container, move to the `/mapd-workspace` folder and execute the python script with the option `--hostname spark-master`:
#
# ```bash
# python /mapd-workspace/notebooks/utils/producer.py --hostname spark-master
# ```
#
# The producer application will be automatically closed when the streaming application terminates.

# %% [markdown]
# ### Running the first streaming application
#
# The first streaming query will be a simple `show` of the DataFrame
# * No processing between `rawMessagesDf` and output sink (`writeStream`)
#
# Output mode is set to `update`, hence every new message received by the TCP source will be processed by the output sink.
# * Output format `console` indicates that the output will be displayed on the screen before being discarded
#
# The streaming query is triggered every 2 seconds
# * refer to the [documentation](https://spark.apache.org/docs/latest/structured-streaming-programming-guide.html#streaming-table-apis) for additional trigger types.

# %%
query = (
    rawMessagesDf
    .writeStream
    .outputMode("update")
    .format("console")
    .trigger(processingTime='2 seconds')
    .option("truncate", False)
    .start()
)
# Out:
# 25/05/15 07:20:41 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-c7298fa4-4585-4f4f-8b9b-f852cd2e16ab. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +-----+
# |value|
# +-----+
# +-----+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Joe", "surname": "Millers", "amount": 310.57, "delta_t": 6.91, "flag": 0} |
# |{"name": "Joe", "surname": "Johnson", "amount": 130.74, "delta_t": 2.16, "flag": 0} |
# |{"name": "John", "surname": "Darby", "amount": 865.48, "delta_t": 5.01, "flag": 0}  |
# |{"name": "Jill", "surname": "Johnson", "amount": 246.15, "delta_t": 3.15, "flag": 1}|
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Jill", "surname": "Johnson", "amount": 519.57, "delta_t": 7.29, "flag": 1} |
# |{"name": "Andy", "surname": "Millers", "amount": 971.14, "delta_t": 9.62, "flag": 0} |
# |{"name": "John", "surname": "Jones", "amount": 53.56, "delta_t": 3.97, "flag": 0}    |
# |{"name": "Jill", "surname": "Darby", "amount": 443.56, "delta_t": 0.72, "flag": 0}   |
# |{"name": "Andy", "surname": "Johnson", "amount": 1.01, "delta_t": 2.61, "flag": 0}   |
# |{"name": "Andy", "surname": "Darby", "amount": 192.73, "delta_t": 8.77, "flag": 0}   |
# |{"name": "Andy", "surname": "Darby", "amount": 382.77, "delta_t": 9.51, "flag": 1}   |
# |{"name": "Alice", "surname": "Johnson", "amount": 225.03, "delta_t": 5.28, "flag": 0}|
# |{"name": "Andy", "surname": "Johnson", "amount": 760.48, "delta_t": 5.73, "flag": 0} |
# |{"name": "Andy", "surname": "Darby", "amount": 870.5, "delta_t": 3.01, "flag": 0}    |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Joe", "surname": "Darby", "amount": 285.43, "delta_t": 2.28, "flag": 1}    |
# |{"name": "Joe", "surname": "Darby", "amount": 600.99, "delta_t": 2.63, "flag": 0}    |
# |{"name": "John", "surname": "Darby", "amount": 700.89, "delta_t": 6.5, "flag": 1}    |
# |{"name": "Andy", "surname": "Smith", "amount": 173.01, "delta_t": 8.64, "flag": 1}   |
# |{"name": "Alice", "surname": "Jones", "amount": 84.17, "delta_t": 2.6, "flag": 0}    |
# |{"name": "Jill", "surname": "Jones", "amount": 821.82, "delta_t": 6.04, "flag": 0}   |
# |{"name": "Alice", "surname": "Millers", "amount": 74.27, "delta_t": 8.63, "flag": 0} |
# |{"name": "Alice", "surname": "Johnson", "amount": 158.23, "delta_t": 1.88, "flag": 1}|
# |{"name": "Andy", "surname": "Smith", "amount": 914.68, "delta_t": 4.31, "flag": 0}   |
# |{"name": "Jill", "surname": "Smith", "amount": 9.77, "delta_t": 4.47, "flag": 0}     |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Jill", "surname": "Smith", "amount": 183.9, "delta_t": 9.61, "flag": 1}    |
# |{"name": "Jill", "surname": "Darby", "amount": 452.17, "delta_t": 2.95, "flag": 1}   |
# |{"name": "Andy", "surname": "Smith", "amount": 152.48, "delta_t": 5.01, "flag": 1}   |
# |{"name": "Alice", "surname": "Smith", "amount": 618.38, "delta_t": 4.81, "flag": 0}  |
# |{"name": "Alice", "surname": "Johnson", "amount": 330.82, "delta_t": 1.28, "flag": 0}|
# |{"name": "Andy", "surname": "Darby", "amount": 526.88, "delta_t": 6.11, "flag": 0}   |
# |{"name": "Jill", "surname": "Johnson", "amount": 271.46, "delta_t": 1.15, "flag": 1} |
# |{"name": "Andy", "surname": "Johnson", "amount": 968.73, "delta_t": 4.57, "flag": 0} |
# |{"name": "John", "surname": "Smith", "amount": 36.19, "delta_t": 4.26, "flag": 1}    |
# |{"name": "Joe", "surname": "Millers", "amount": 24.57, "delta_t": 6.28, "flag": 1}   |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "John", "surname": "Smith", "amount": 618.69, "delta_t": 1.97, "flag": 0}  |
# |{"name": "Joe", "surname": "Johnson", "amount": 824.1, "delta_t": 3.48, "flag": 0}  |
# |{"name": "Alice", "surname": "Jones", "amount": 840.47, "delta_t": 1.98, "flag": 1} |
# |{"name": "Jill", "surname": "Johnson", "amount": 19.61, "delta_t": 6.84, "flag": 0} |
# |{"name": "Jill", "surname": "Millers", "amount": 708.32, "delta_t": 0.73, "flag": 0}|
# |{"name": "Alice", "surname": "Smith", "amount": 159.11, "delta_t": 2.47, "flag": 0} |
# |{"name": "Alice", "surname": "Darby", "amount": 213.98, "delta_t": 7.81, "flag": 0} |
# |{"name": "Andy", "surname": "Smith", "amount": 409.61, "delta_t": 7.53, "flag": 0}  |
# |{"name": "Andy", "surname": "Smith", "amount": 239.49, "delta_t": 5.73, "flag": 1}  |
# |{"name": "Joe", "surname": "Johnson", "amount": 851.95, "delta_t": 6.2, "flag": 1}  |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Joe", "surname": "Johnson", "amount": 647.44, "delta_t": 1.71, "flag": 0} |
# |{"name": "Jill", "surname": "Jones", "amount": 528.86, "delta_t": 8.6, "flag": 0}   |
# |{"name": "Joe", "surname": "Jones", "amount": 558.88, "delta_t": 5.9, "flag": 0}    |
# |{"name": "John", "surname": "Darby", "amount": 388.67, "delta_t": 1.92, "flag": 0}  |
# |{"name": "Andy", "surname": "Millers", "amount": 526.04, "delta_t": 4.98, "flag": 1}|
# |{"name": "Alice", "surname": "Smith", "amount": 209.69, "delta_t": 4.06, "flag": 0} |
# |{"name": "Jill", "surname": "Jones", "amount": 975.87, "delta_t": 1.52, "flag": 0}  |
# |{"name": "Andy", "surname": "Darby", "amount": 199.6, "delta_t": 6.97, "flag": 0}   |
# |{"name": "John", "surname": "Johnson", "amount": 263.98, "delta_t": 2.33, "flag": 0}|
# |{"name": "John", "surname": "Darby", "amount": 443.16, "delta_t": 0.23, "flag": 0}  |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 7
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Alice", "surname": "Millers", "amount": 381.42, "delta_t": 0.32, "flag": 0}|
# |{"name": "John", "surname": "Millers", "amount": 54.67, "delta_t": 4.47, "flag": 0}  |
# |{"name": "Joe", "surname": "Millers", "amount": 631.4, "delta_t": 7.55, "flag": 1}   |
# |{"name": "Alice", "surname": "Smith", "amount": 33.63, "delta_t": 2.51, "flag": 0}   |
# |{"name": "Andy", "surname": "Jones", "amount": 83.53, "delta_t": 4.64, "flag": 0}    |
# |{"name": "Joe", "surname": "Darby", "amount": 834.66, "delta_t": 0.02, "flag": 1}    |
# |{"name": "Jill", "surname": "Johnson", "amount": 619.78, "delta_t": 8.12, "flag": 0} |
# |{"name": "Andy", "surname": "Smith", "amount": 691.42, "delta_t": 7.23, "flag": 0}   |
# |{"name": "Andy", "surname": "Jones", "amount": 736.83, "delta_t": 3.66, "flag": 1}   |
# |{"name": "Joe", "surname": "Johnson", "amount": 921.1, "delta_t": 2.42, "flag": 0}   |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 8
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Jill", "surname": "Darby", "amount": 148.51, "delta_t": 1.19, "flag": 0}  |
# |{"name": "Alice", "surname": "Smith", "amount": 255.52, "delta_t": 6.57, "flag": 0} |
# |{"name": "Andy", "surname": "Darby", "amount": 517.59, "delta_t": 9.92, "flag": 0}  |
# |{"name": "Andy", "surname": "Darby", "amount": 771.7, "delta_t": 7.38, "flag": 0}   |
# |{"name": "Andy", "surname": "Johnson", "amount": 276.57, "delta_t": 1.48, "flag": 0}|
# |{"name": "Jill", "surname": "Johnson", "amount": 246.03, "delta_t": 4.52, "flag": 1}|
# |{"name": "John", "surname": "Johnson", "amount": 614.11, "delta_t": 0.05, "flag": 0}|
# |{"name": "Andy", "surname": "Jones", "amount": 929.32, "delta_t": 0.18, "flag": 0}  |
# |{"name": "Joe", "surname": "Smith", "amount": 932.88, "delta_t": 5.32, "flag": 0}   |
# |{"name": "Alice", "surname": "Smith", "amount": 761.35, "delta_t": 7.36, "flag": 0} |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 9
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Andy", "surname": "Johnson", "amount": 730.76, "delta_t": 3.0, "flag": 0}  |
# |{"name": "Jill", "surname": "Millers", "amount": 185.01, "delta_t": 7.09, "flag": 0} |
# |{"name": "Alice", "surname": "Millers", "amount": 286.7, "delta_t": 2.8, "flag": 1}  |
# |{"name": "Alice", "surname": "Smith", "amount": 462.09, "delta_t": 7.63, "flag": 0}  |
# |{"name": "Joe", "surname": "Darby", "amount": 52.28, "delta_t": 2.64, "flag": 1}     |
# |{"name": "Jill", "surname": "Darby", "amount": 257.81, "delta_t": 3.88, "flag": 0}   |
# |{"name": "Alice", "surname": "Johnson", "amount": 224.84, "delta_t": 1.71, "flag": 1}|
# |{"name": "Jill", "surname": "Johnson", "amount": 81.22, "delta_t": 8.61, "flag": 0}  |
# |{"name": "Jill", "surname": "Darby", "amount": 262.16, "delta_t": 2.31, "flag": 0}   |
# |{"name": "John", "surname": "Johnson", "amount": 632.55, "delta_t": 6.58, "flag": 1} |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 10
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Joe", "surname": "Smith", "amount": 613.5, "delta_t": 6.51, "flag": 0}    |
# |{"name": "Alice", "surname": "Smith", "amount": 373.66, "delta_t": 5.39, "flag": 0} |
# |{"name": "Alice", "surname": "Jones", "amount": 915.35, "delta_t": 3.84, "flag": 0} |
# |{"name": "Andy", "surname": "Johnson", "amount": 379.16, "delta_t": 2.76, "flag": 0}|
# |{"name": "Alice", "surname": "Jones", "amount": 690.29, "delta_t": 6.17, "flag": 0} |
# |{"name": "Andy", "surname": "Johnson", "amount": 485.66, "delta_t": 9.16, "flag": 0}|
# |{"name": "Alice", "surname": "Darby", "amount": 371.43, "delta_t": 4.04, "flag": 0} |
# |{"name": "Andy", "surname": "Darby", "amount": 956.76, "delta_t": 8.52, "flag": 1}  |
# |{"name": "Joe", "surname": "Millers", "amount": 263.5, "delta_t": 9.06, "flag": 1}  |
# |{"name": "Joe", "surname": "Smith", "amount": 333.51, "delta_t": 1.52, "flag": 0}   |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 11
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Joe", "surname": "Darby", "amount": 304.78, "delta_t": 6.51, "flag": 1}   |
# |{"name": "Jill", "surname": "Johnson", "amount": 752.39, "delta_t": 6.91, "flag": 0}|
# |{"name": "Alice", "surname": "Johnson", "amount": 698.8, "delta_t": 6.56, "flag": 0}|
# |{"name": "Andy", "surname": "Millers", "amount": 423.06, "delta_t": 9.8, "flag": 0} |
# |{"name": "Andy", "surname": "Jones", "amount": 444.02, "delta_t": 6.5, "flag": 0}   |
# |{"name": "Andy", "surname": "Darby", "amount": 561.76, "delta_t": 9.2, "flag": 1}   |
# |{"name": "Andy", "surname": "Jones", "amount": 604.53, "delta_t": 1.5, "flag": 0}   |
# |{"name": "Andy", "surname": "Darby", "amount": 653.04, "delta_t": 8.53, "flag": 0}  |
# |{"name": "Jill", "surname": "Jones", "amount": 184.06, "delta_t": 7.97, "flag": 0}  |
# |{"name": "Jill", "surname": "Jones", "amount": 608.6, "delta_t": 6.69, "flag": 0}   |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 12
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "John", "surname": "Darby", "amount": 486.7, "delta_t": 5.84, "flag": 0}    |
# |{"name": "John", "surname": "Smith", "amount": 344.96, "delta_t": 4.0, "flag": 0}    |
# |{"name": "Andy", "surname": "Millers", "amount": 340.25, "delta_t": 3.45, "flag": 0} |
# |{"name": "Andy", "surname": "Darby", "amount": 804.62, "delta_t": 6.5, "flag": 1}    |
# |{"name": "Joe", "surname": "Darby", "amount": 791.01, "delta_t": 5.52, "flag": 0}    |
# |{"name": "Alice", "surname": "Millers", "amount": 404.65, "delta_t": 0.94, "flag": 0}|
# |{"name": "Alice", "surname": "Smith", "amount": 767.2, "delta_t": 1.23, "flag": 0}   |
# |{"name": "Jill", "surname": "Johnson", "amount": 517.13, "delta_t": 0.24, "flag": 1} |
# |{"name": "Alice", "surname": "Johnson", "amount": 167.23, "delta_t": 6.92, "flag": 0}|
# |{"name": "Alice", "surname": "Smith", "amount": 360.04, "delta_t": 9.48, "flag": 1}  |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 13
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Alice", "surname": "Smith", "amount": 579.86, "delta_t": 3.82, "flag": 0} |
# |{"name": "Alice", "surname": "Smith", "amount": 559.87, "delta_t": 3.61, "flag": 1} |
# |{"name": "Andy", "surname": "Millers", "amount": 582.44, "delta_t": 7.92, "flag": 1}|
# |{"name": "Joe", "surname": "Johnson", "amount": 417.78, "delta_t": 2.9, "flag": 1}  |
# |{"name": "Jill", "surname": "Darby", "amount": 897.79, "delta_t": 6.47, "flag": 0}  |
# |{"name": "Andy", "surname": "Darby", "amount": 780.34, "delta_t": 5.35, "flag": 0}  |
# |{"name": "Alice", "surname": "Millers", "amount": 89.09, "delta_t": 3.84, "flag": 0}|
# |{"name": "Alice", "surname": "Darby", "amount": 268.32, "delta_t": 2.94, "flag": 0} |
# |{"name": "Joe", "surname": "Smith", "amount": 790.02, "delta_t": 4.38, "flag": 0}   |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 14
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Andy", "surname": "Darby", "amount": 521.51, "delta_t": 9.49, "flag": 0}  |
# |{"name": "Alice", "surname": "Jones", "amount": 581.47, "delta_t": 4.46, "flag": 0} |
# |{"name": "John", "surname": "Johnson", "amount": 364.17, "delta_t": 6.06, "flag": 1}|
# |{"name": "Joe", "surname": "Johnson", "amount": 542.47, "delta_t": 9.04, "flag": 1} |
# |{"name": "John", "surname": "Millers", "amount": 262.25, "delta_t": 9.67, "flag": 0}|
# |{"name": "Jill", "surname": "Jones", "amount": 444.57, "delta_t": 8.89, "flag": 0}  |
# |{"name": "Andy", "surname": "Smith", "amount": 124.48, "delta_t": 8.63, "flag": 0}  |
# |{"name": "Joe", "surname": "Smith", "amount": 376.88, "delta_t": 6.89, "flag": 1}   |
# |{"name": "Andy", "surname": "Millers", "amount": 343.6, "delta_t": 8.77, "flag": 1} |
# |{"name": "John", "surname": "Johnson", "amount": 406.5, "delta_t": 2.36, "flag": 0} |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 15
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Andy", "surname": "Darby", "amount": 117.21, "delta_t": 8.67, "flag": 1}   |
# |{"name": "Jill", "surname": "Smith", "amount": 838.76, "delta_t": 3.22, "flag": 0}   |
# |{"name": "Andy", "surname": "Millers", "amount": 500.71, "delta_t": 4.74, "flag": 0} |
# |{"name": "Jill", "surname": "Millers", "amount": 923.86, "delta_t": 8.07, "flag": 1} |
# |{"name": "John", "surname": "Johnson", "amount": 563.87, "delta_t": 3.36, "flag": 0} |
# |{"name": "Andy", "surname": "Jones", "amount": 308.14, "delta_t": 1.47, "flag": 0}   |
# |{"name": "Jill", "surname": "Millers", "amount": 120.45, "delta_t": 8.76, "flag": 0} |
# |{"name": "John", "surname": "Millers", "amount": 92.03, "delta_t": 6.13, "flag": 0}  |
# |{"name": "Alice", "surname": "Millers", "amount": 571.06, "delta_t": 2.84, "flag": 0}|
# |{"name": "Jill", "surname": "Darby", "amount": 671.25, "delta_t": 9.47, "flag": 0}   |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 16
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Alice", "surname": "Johnson", "amount": 35.55, "delta_t": 5.91, "flag": 0}|
# |{"name": "Andy", "surname": "Johnson", "amount": 537.86, "delta_t": 1.24, "flag": 0}|
# |{"name": "Joe", "surname": "Darby", "amount": 395.78, "delta_t": 9.9, "flag": 0}    |
# |{"name": "Joe", "surname": "Johnson", "amount": 192.26, "delta_t": 2.68, "flag": 0} |
# |{"name": "Alice", "surname": "Darby", "amount": 25.7, "delta_t": 1.26, "flag": 0}   |
# |{"name": "Jill", "surname": "Smith", "amount": 312.62, "delta_t": 7.94, "flag": 1}  |
# |{"name": "Alice", "surname": "Jones", "amount": 96.36, "delta_t": 4.48, "flag": 0}  |
# |{"name": "Jill", "surname": "Smith", "amount": 987.83, "delta_t": 0.35, "flag": 0}  |
# |{"name": "Andy", "surname": "Millers", "amount": 10.4, "delta_t": 0.43, "flag": 1}  |
# |{"name": "Jill", "surname": "Jones", "amount": 727.83, "delta_t": 4.67, "flag": 0}  |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 17
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Joe", "surname": "Darby", "amount": 706.08, "delta_t": 2.8, "flag": 0}     |
# |{"name": "Andy", "surname": "Millers", "amount": 509.26, "delta_t": 2.53, "flag": 0} |
# |{"name": "Alice", "surname": "Jones", "amount": 349.46, "delta_t": 2.04, "flag": 0}  |
# |{"name": "Joe", "surname": "Johnson", "amount": 845.21, "delta_t": 6.5, "flag": 1}   |
# |{"name": "Joe", "surname": "Millers", "amount": 496.03, "delta_t": 0.41, "flag": 0}  |
# |{"name": "Jill", "surname": "Darby", "amount": 274.89, "delta_t": 5.8, "flag": 0}    |
# |{"name": "Joe", "surname": "Millers", "amount": 964.53, "delta_t": 7.8, "flag": 0}   |
# |{"name": "Alice", "surname": "Millers", "amount": 153.12, "delta_t": 9.57, "flag": 0}|
# |{"name": "Jill", "surname": "Jones", "amount": 169.84, "delta_t": 6.51, "flag": 1}   |
# |{"name": "Andy", "surname": "Darby", "amount": 857.91, "delta_t": 1.48, "flag": 0}   |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 18
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Alice", "surname": "Johnson", "amount": 531.14, "delta_t": 9.73, "flag": 0}|
# |{"name": "Joe", "surname": "Darby", "amount": 79.03, "delta_t": 5.07, "flag": 0}     |
# |{"name": "Jill", "surname": "Smith", "amount": 136.14, "delta_t": 2.48, "flag": 0}   |
# |{"name": "Andy", "surname": "Johnson", "amount": 417.24, "delta_t": 7.85, "flag": 0} |
# |{"name": "Alice", "surname": "Darby", "amount": 552.16, "delta_t": 0.62, "flag": 1}  |
# |{"name": "Joe", "surname": "Johnson", "amount": 203.76, "delta_t": 9.0, "flag": 0}   |
# |{"name": "John", "surname": "Millers", "amount": 506.29, "delta_t": 8.94, "flag": 0} |
# |{"name": "Alice", "surname": "Millers", "amount": 39.49, "delta_t": 5.34, "flag": 0} |
# |{"name": "Jill", "surname": "Millers", "amount": 464.02, "delta_t": 9.0, "flag": 0}  |
# |{"name": "Jill", "surname": "Johnson", "amount": 755.52, "delta_t": 2.44, "flag": 0} |
# |{"name": "Alice", "surname": "Johnson", "amount": 823.84, "delta_t": 0.68, "flag": 0}|
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 19
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Jill", "surname": "Millers", "amount": 706.43, "delta_t": 5.33, "flag": 0}|
# |{"name": "Andy", "surname": "Millers", "amount": 281.27, "delta_t": 4.02, "flag": 0}|
# |{"name": "Andy", "surname": "Smith", "amount": 25.24, "delta_t": 7.19, "flag": 0}   |
# |{"name": "Joe", "surname": "Jones", "amount": 351.44, "delta_t": 7.87, "flag": 1}   |
# |{"name": "Alice", "surname": "Jones", "amount": 583.88, "delta_t": 6.47, "flag": 1} |
# |{"name": "Joe", "surname": "Jones", "amount": 104.2, "delta_t": 3.76, "flag": 0}    |
# |{"name": "Joe", "surname": "Millers", "amount": 50.37, "delta_t": 0.75, "flag": 0}  |
# |{"name": "Alice", "surname": "Darby", "amount": 963.72, "delta_t": 5.14, "flag": 0} |
# |{"name": "Jill", "surname": "Darby", "amount": 645.18, "delta_t": 8.51, "flag": 0}  |
# |{"name": "Andy", "surname": "Millers", "amount": 977.68, "delta_t": 1.88, "flag": 0}|
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 20
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Alice", "surname": "Smith", "amount": 427.67, "delta_t": 3.02, "flag": 1}  |
# |{"name": "Joe", "surname": "Darby", "amount": 674.56, "delta_t": 6.65, "flag": 1}    |
# |{"name": "Jill", "surname": "Darby", "amount": 633.84, "delta_t": 4.94, "flag": 0}   |
# |{"name": "Jill", "surname": "Smith", "amount": 568.2, "delta_t": 2.77, "flag": 1}    |
# |{"name": "Alice", "surname": "Millers", "amount": 113.56, "delta_t": 9.99, "flag": 0}|
# |{"name": "Andy", "surname": "Darby", "amount": 536.11, "delta_t": 4.0, "flag": 0}    |
# |{"name": "Joe", "surname": "Darby", "amount": 867.45, "delta_t": 1.49, "flag": 0}    |
# |{"name": "Jill", "surname": "Darby", "amount": 410.56, "delta_t": 5.31, "flag": 0}   |
# |{"name": "Joe", "surname": "Jones", "amount": 202.85, "delta_t": 5.74, "flag": 0}    |
# |{"name": "Jill", "surname": "Darby", "amount": 355.51, "delta_t": 6.94, "flag": 1}   |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 21
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Jill", "surname": "Smith", "amount": 483.99, "delta_t": 7.88, "flag": 0}   |
# |{"name": "John", "surname": "Jones", "amount": 759.53, "delta_t": 1.53, "flag": 0}   |
# |{"name": "Andy", "surname": "Johnson", "amount": 71.88, "delta_t": 5.56, "flag": 0}  |
# |{"name": "Alice", "surname": "Johnson", "amount": 758.71, "delta_t": 6.46, "flag": 0}|
# |{"name": "Joe", "surname": "Millers", "amount": 912.04, "delta_t": 9.74, "flag": 0}  |
# |{"name": "Andy", "surname": "Smith", "amount": 420.09, "delta_t": 0.67, "flag": 0}   |
# |{"name": "Jill", "surname": "Millers", "amount": 647.79, "delta_t": 3.77, "flag": 0} |
# |{"name": "Andy", "surname": "Darby", "amount": 656.24, "delta_t": 7.68, "flag": 0}   |
# |{"name": "Andy", "surname": "Darby", "amount": 406.07, "delta_t": 8.33, "flag": 0}   |
# |{"name": "John", "surname": "Smith", "amount": 797.97, "delta_t": 9.77, "flag": 1}   |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 22
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "John", "surname": "Jones", "amount": 747.32, "delta_t": 6.66, "flag": 1}  |
# |{"name": "John", "surname": "Darby", "amount": 95.46, "delta_t": 6.28, "flag": 0}   |
# |{"name": "Jill", "surname": "Jones", "amount": 887.69, "delta_t": 8.75, "flag": 0}  |
# |{"name": "Alice", "surname": "Smith", "amount": 901.68, "delta_t": 8.23, "flag": 0} |
# |{"name": "Joe", "surname": "Millers", "amount": 195.76, "delta_t": 5.39, "flag": 0} |
# |{"name": "John", "surname": "Millers", "amount": 179.67, "delta_t": 6.9, "flag": 0} |
# |{"name": "Jill", "surname": "Millers", "amount": 102.12, "delta_t": 7.36, "flag": 0}|
# |{"name": "Andy", "surname": "Jones", "amount": 788.58, "delta_t": 7.0, "flag": 0}   |
# |{"name": "Andy", "surname": "Smith", "amount": 71.95, "delta_t": 8.33, "flag": 1}   |
# |{"name": "Joe", "surname": "Millers", "amount": 17.08, "delta_t": 1.6, "flag": 1}   |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 23
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Joe", "surname": "Millers", "amount": 259.19, "delta_t": 0.6, "flag": 0}  |
# |{"name": "Jill", "surname": "Darby", "amount": 292.52, "delta_t": 5.72, "flag": 1}  |
# |{"name": "John", "surname": "Millers", "amount": 782.81, "delta_t": 6.63, "flag": 0}|
# |{"name": "Andy", "surname": "Johnson", "amount": 707.71, "delta_t": 1.92, "flag": 0}|
# |{"name": "Jill", "surname": "Johnson", "amount": 334.46, "delta_t": 9.31, "flag": 0}|
# |{"name": "Alice", "surname": "Smith", "amount": 631.75, "delta_t": 8.74, "flag": 0} |
# |{"name": "Jill", "surname": "Millers", "amount": 656.57, "delta_t": 8.99, "flag": 0}|
# |{"name": "Alice", "surname": "Millers", "amount": 750.6, "delta_t": 0.16, "flag": 0}|
# |{"name": "Joe", "surname": "Jones", "amount": 963.55, "delta_t": 0.9, "flag": 0}    |
# |{"name": "Jill", "surname": "Jones", "amount": 528.42, "delta_t": 2.12, "flag": 0}  |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 24
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Jill", "surname": "Johnson", "amount": 273.03, "delta_t": 9.0, "flag": 0}  |
# |{"name": "Jill", "surname": "Johnson", "amount": 309.24, "delta_t": 8.85, "flag": 0} |
# |{"name": "Andy", "surname": "Smith", "amount": 963.13, "delta_t": 6.62, "flag": 0}   |
# |{"name": "Joe", "surname": "Millers", "amount": 166.8, "delta_t": 3.19, "flag": 0}   |
# |{"name": "Alice", "surname": "Millers", "amount": 736.94, "delta_t": 6.78, "flag": 0}|
# |{"name": "Joe", "surname": "Jones", "amount": 148.43, "delta_t": 0.09, "flag": 0}    |
# |{"name": "Jill", "surname": "Darby", "amount": 935.6, "delta_t": 0.83, "flag": 0}    |
# |{"name": "John", "surname": "Millers", "amount": 729.31, "delta_t": 8.59, "flag": 0} |
# |{"name": "Joe", "surname": "Johnson", "amount": 232.66, "delta_t": 4.75, "flag": 0}  |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 25
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Andy", "surname": "Jones", "amount": 784.68, "delta_t": 3.17, "flag": 1}  |
# |{"name": "Andy", "surname": "Jones", "amount": 743.09, "delta_t": 3.93, "flag": 0}  |
# |{"name": "Jill", "surname": "Jones", "amount": 687.47, "delta_t": 4.6, "flag": 0}   |
# |{"name": "John", "surname": "Jones", "amount": 668.01, "delta_t": 2.45, "flag": 0}  |
# |{"name": "Joe", "surname": "Jones", "amount": 939.3, "delta_t": 4.7, "flag": 0}     |
# |{"name": "Alice", "surname": "Millers", "amount": 258.03, "delta_t": 2.3, "flag": 0}|
# |{"name": "Joe", "surname": "Johnson", "amount": 193.54, "delta_t": 2.27, "flag": 0} |
# |{"name": "Andy", "surname": "Smith", "amount": 86.96, "delta_t": 1.76, "flag": 1}   |
# |{"name": "John", "surname": "Darby", "amount": 237.94, "delta_t": 2.25, "flag": 0}  |
# |{"name": "Joe", "surname": "Smith", "amount": 312.57, "delta_t": 1.35, "flag": 0}   |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 26
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Joe", "surname": "Darby", "amount": 778.83, "delta_t": 1.82, "flag": 1}   |
# |{"name": "Jill", "surname": "Johnson", "amount": 769.43, "delta_t": 4.43, "flag": 0}|
# |{"name": "Joe", "surname": "Johnson", "amount": 379.93, "delta_t": 5.27, "flag": 0} |
# |{"name": "Jill", "surname": "Smith", "amount": 2.98, "delta_t": 1.54, "flag": 0}    |
# |{"name": "Andy", "surname": "Johnson", "amount": 191.72, "delta_t": 6.64, "flag": 0}|
# |{"name": "Andy", "surname": "Johnson", "amount": 915.44, "delta_t": 2.5, "flag": 0} |
# |{"name": "Alice", "surname": "Smith", "amount": 978.13, "delta_t": 7.7, "flag": 0}  |
# |{"name": "John", "surname": "Darby", "amount": 784.84, "delta_t": 6.71, "flag": 0}  |
# |{"name": "Alice", "surname": "Jones", "amount": 587.71, "delta_t": 7.63, "flag": 1} |
# |{"name": "Alice", "surname": "Darby", "amount": 452.96, "delta_t": 5.07, "flag": 0} |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 27
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Alice", "surname": "Darby", "amount": 500.81, "delta_t": 1.95, "flag": 0} |
# |{"name": "Andy", "surname": "Johnson", "amount": 69.62, "delta_t": 6.96, "flag": 1} |
# |{"name": "John", "surname": "Darby", "amount": 701.52, "delta_t": 9.9, "flag": 0}   |
# |{"name": "Joe", "surname": "Darby", "amount": 350.82, "delta_t": 7.62, "flag": 0}   |
# |{"name": "John", "surname": "Millers", "amount": 118.13, "delta_t": 5.66, "flag": 1}|
# |{"name": "Joe", "surname": "Johnson", "amount": 359.92, "delta_t": 0.4, "flag": 0}  |
# |{"name": "Andy", "surname": "Johnson", "amount": 314.61, "delta_t": 3.71, "flag": 0}|
# |{"name": "Jill", "surname": "Jones", "amount": 82.94, "delta_t": 4.08, "flag": 1}   |
# |{"name": "Alice", "surname": "Smith", "amount": 584.6, "delta_t": 5.79, "flag": 0}  |
# |{"name": "John", "surname": "Darby", "amount": 354.65, "delta_t": 9.54, "flag": 0}  |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 28
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "John", "surname": "Smith", "amount": 684.3, "delta_t": 0.72, "flag": 1}   |
# |{"name": "Jill", "surname": "Johnson", "amount": 169.27, "delta_t": 2.63, "flag": 0}|
# |{"name": "Alice", "surname": "Darby", "amount": 578.15, "delta_t": 7.48, "flag": 0} |
# |{"name": "Joe", "surname": "Millers", "amount": 323.33, "delta_t": 4.72, "flag": 0} |
# |{"name": "John", "surname": "Smith", "amount": 216.85, "delta_t": 6.4, "flag": 0}   |
# |{"name": "Alice", "surname": "Johnson", "amount": 327.62, "delta_t": 9.1, "flag": 0}|
# |{"name": "John", "surname": "Millers", "amount": 31.26, "delta_t": 5.98, "flag": 0} |
# |{"name": "Jill", "surname": "Smith", "amount": 305.5, "delta_t": 3.85, "flag": 0}   |
# |{"name": "John", "surname": "Johnson", "amount": 932.62, "delta_t": 9.28, "flag": 0}|
# |{"name": "Joe", "surname": "Darby", "amount": 509.09, "delta_t": 3.93, "flag": 0}   |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 29
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Alice", "surname": "Jones", "amount": 896.9, "delta_t": 3.5, "flag": 1}   |
# |{"name": "Joe", "surname": "Jones", "amount": 486.6, "delta_t": 7.23, "flag": 0}    |
# |{"name": "Jill", "surname": "Johnson", "amount": 926.41, "delta_t": 9.5, "flag": 0} |
# |{"name": "Alice", "surname": "Jones", "amount": 816.7, "delta_t": 2.22, "flag": 0}  |
# |{"name": "Andy", "surname": "Smith", "amount": 645.72, "delta_t": 7.29, "flag": 0}  |
# |{"name": "Jill", "surname": "Millers", "amount": 843.83, "delta_t": 0.52, "flag": 0}|
# |{"name": "Andy", "surname": "Jones", "amount": 999.59, "delta_t": 8.26, "flag": 0}  |
# |{"name": "Jill", "surname": "Jones", "amount": 309.55, "delta_t": 2.01, "flag": 0}  |
# |{"name": "Andy", "surname": "Darby", "amount": 753.59, "delta_t": 7.14, "flag": 0}  |
# |{"name": "Alice", "surname": "Jones", "amount": 313.12, "delta_t": 1.04, "flag": 1} |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 30
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Alice", "surname": "Smith", "amount": 626.01, "delta_t": 7.74, "flag": 0} |
# |{"name": "Andy", "surname": "Millers", "amount": 746.99, "delta_t": 5.8, "flag": 0} |
# |{"name": "Joe", "surname": "Millers", "amount": 529.65, "delta_t": 5.63, "flag": 0} |
# |{"name": "John", "surname": "Darby", "amount": 217.88, "delta_t": 4.73, "flag": 0}  |
# |{"name": "Andy", "surname": "Darby", "amount": 248.36, "delta_t": 1.71, "flag": 1}  |
# |{"name": "Alice", "surname": "Millers", "amount": 811.1, "delta_t": 5.14, "flag": 0}|
# |{"name": "Joe", "surname": "Millers", "amount": 200.53, "delta_t": 8.69, "flag": 0} |
# |{"name": "Andy", "surname": "Darby", "amount": 72.55, "delta_t": 1.46, "flag": 1}   |
# |{"name": "Alice", "surname": "Jones", "amount": 278.12, "delta_t": 0.52, "flag": 0} |
# |{"name": "Jill", "surname": "Jones", "amount": 374.23, "delta_t": 9.38, "flag": 0}  |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 31
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Jill", "surname": "Jones", "amount": 304.08, "delta_t": 1.28, "flag": 0}  |
# |{"name": "Alice", "surname": "Smith", "amount": 582.56, "delta_t": 9.52, "flag": 0} |
# |{"name": "Alice", "surname": "Darby", "amount": 213.02, "delta_t": 2.49, "flag": 0} |
# |{"name": "Alice", "surname": "Darby", "amount": 448.96, "delta_t": 1.53, "flag": 0} |
# |{"name": "Andy", "surname": "Darby", "amount": 931.02, "delta_t": 5.67, "flag": 0}  |
# |{"name": "Jill", "surname": "Johnson", "amount": 486.69, "delta_t": 9.16, "flag": 0}|
# |{"name": "Jill", "surname": "Johnson", "amount": 313.28, "delta_t": 1.38, "flag": 0}|
# |{"name": "Joe", "surname": "Darby", "amount": 129.92, "delta_t": 4.27, "flag": 0}   |
# |{"name": "Alice", "surname": "Smith", "amount": 515.72, "delta_t": 5.43, "flag": 0} |
# |{"name": "John", "surname": "Darby", "amount": 496.24, "delta_t": 1.86, "flag": 0}  |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 32
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Alice", "surname": "Millers", "amount": 428.27, "delta_t": 2.08, "flag": 0}|
# |{"name": "Joe", "surname": "Millers", "amount": 931.07, "delta_t": 4.88, "flag": 0}  |
# |{"name": "Joe", "surname": "Jones", "amount": 68.68, "delta_t": 6.92, "flag": 0}     |
# |{"name": "Joe", "surname": "Smith", "amount": 655.45, "delta_t": 3.09, "flag": 0}    |
# |{"name": "John", "surname": "Darby", "amount": 610.21, "delta_t": 6.99, "flag": 0}   |
# |{"name": "Jill", "surname": "Johnson", "amount": 917.49, "delta_t": 3.03, "flag": 0} |
# |{"name": "John", "surname": "Jones", "amount": 879.41, "delta_t": 8.65, "flag": 0}   |
# |{"name": "John", "surname": "Johnson", "amount": 35.86, "delta_t": 7.66, "flag": 0}  |
# |{"name": "Alice", "surname": "Smith", "amount": 579.0, "delta_t": 6.64, "flag": 0}   |
# |{"name": "Joe", "surname": "Millers", "amount": 235.62, "delta_t": 9.51, "flag": 0}  |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 33
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Andy", "surname": "Millers", "amount": 609.44, "delta_t": 2.59, "flag": 0} |
# |{"name": "Andy", "surname": "Jones", "amount": 886.64, "delta_t": 7.87, "flag": 1}   |
# |{"name": "Alice", "surname": "Jones", "amount": 140.24, "delta_t": 1.42, "flag": 0}  |
# |{"name": "Alice", "surname": "Johnson", "amount": 894.37, "delta_t": 0.63, "flag": 0}|
# |{"name": "Alice", "surname": "Darby", "amount": 724.58, "delta_t": 5.77, "flag": 0}  |
# |{"name": "John", "surname": "Jones", "amount": 826.22, "delta_t": 7.49, "flag": 1}   |
# |{"name": "Joe", "surname": "Jones", "amount": 915.84, "delta_t": 3.6, "flag": 0}     |
# |{"name": "Joe", "surname": "Jones", "amount": 265.28, "delta_t": 1.11, "flag": 0}    |
# |{"name": "Andy", "surname": "Darby", "amount": 35.48, "delta_t": 6.69, "flag": 0}    |
# |{"name": "Alice", "surname": "Smith", "amount": 19.05, "delta_t": 9.74, "flag": 0}   |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 34
# -------------------------------------------
# +-----------------------------------------------------------------------------------+
# |value                                                                              |
# +-----------------------------------------------------------------------------------+
# |{"name": "Joe", "surname": "Millers", "amount": 5.59, "delta_t": 5.64, "flag": 0}  |
# |{"name": "Jill", "surname": "Smith", "amount": 800.95, "delta_t": 8.34, "flag": 0} |
# |{"name": "Alice", "surname": "Darby", "amount": 394.85, "delta_t": 2.44, "flag": 1}|
# |{"name": "Joe", "surname": "Smith", "amount": 68.69, "delta_t": 5.23, "flag": 0}   |
# |{"name": "Alice", "surname": "Darby", "amount": 595.4, "delta_t": 0.71, "flag": 1} |
# |{"name": "Andy", "surname": "Johnson", "amount": 86.67, "delta_t": 6.55, "flag": 0}|
# |{"name": "Jill", "surname": "Johnson", "amount": 978.32, "delta_t": 0.8, "flag": 1}|
# |{"name": "John", "surname": "Smith", "amount": 794.07, "delta_t": 4.64, "flag": 0} |
# |{"name": "Joe", "surname": "Jones", "amount": 26.78, "delta_t": 9.69, "flag": 0}   |
# |{"name": "Alice", "surname": "Darby", "amount": 246.22, "delta_t": 7.2, "flag": 1} |
# +-----------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 35
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Jill", "surname": "Darby", "amount": 58.32, "delta_t": 5.9, "flag": 0}    |
# |{"name": "Joe", "surname": "Jones", "amount": 747.96, "delta_t": 2.15, "flag": 0}   |
# |{"name": "John", "surname": "Johnson", "amount": 451.76, "delta_t": 2.47, "flag": 0}|
# |{"name": "Joe", "surname": "Johnson", "amount": 848.34, "delta_t": 3.91, "flag": 0} |
# |{"name": "Andy", "surname": "Smith", "amount": 278.12, "delta_t": 4.33, "flag": 0}  |
# |{"name": "John", "surname": "Darby", "amount": 479.54, "delta_t": 9.38, "flag": 1}  |
# |{"name": "John", "surname": "Johnson", "amount": 718.71, "delta_t": 0.69, "flag": 0}|
# |{"name": "Alice", "surname": "Smith", "amount": 775.23, "delta_t": 8.66, "flag": 1} |
# |{"name": "Andy", "surname": "Johnson", "amount": 95.35, "delta_t": 8.92, "flag": 0} |
# |{"name": "John", "surname": "Darby", "amount": 853.19, "delta_t": 4.95, "flag": 0}  |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 36
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Joe", "surname": "Darby", "amount": 328.9, "delta_t": 3.89, "flag": 0}     |
# |{"name": "Alice", "surname": "Darby", "amount": 828.71, "delta_t": 2.77, "flag": 0}  |
# |{"name": "Alice", "surname": "Johnson", "amount": 271.95, "delta_t": 0.28, "flag": 0}|
# |{"name": "Jill", "surname": "Johnson", "amount": 872.69, "delta_t": 5.89, "flag": 0} |
# |{"name": "Andy", "surname": "Darby", "amount": 568.43, "delta_t": 8.34, "flag": 0}   |
# |{"name": "Andy", "surname": "Jones", "amount": 363.25, "delta_t": 0.41, "flag": 0}   |
# |{"name": "Jill", "surname": "Darby", "amount": 693.04, "delta_t": 4.84, "flag": 1}   |
# |{"name": "John", "surname": "Jones", "amount": 540.38, "delta_t": 2.62, "flag": 1}   |
# |{"name": "John", "surname": "Jones", "amount": 373.16, "delta_t": 0.16, "flag": 0}   |
# |{"name": "Joe", "surname": "Johnson", "amount": 965.84, "delta_t": 9.34, "flag": 1}  |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 37
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "John", "surname": "Darby", "amount": 428.73, "delta_t": 7.02, "flag": 1}   |
# ...
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 124
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Joe", "surname": "Millers", "amount": 370.18, "delta_t": 7.01, "flag": 0} |
# |{"name": "Joe", "surname": "Jones", "amount": 838.05, "delta_t": 6.61, "flag": 1}   |
# |{"name": "Jill", "surname": "Darby", "amount": 542.22, "delta_t": 3.43, "flag": 0}  |
# |{"name": "Andy", "surname": "Jones", "amount": 222.73, "delta_t": 2.7, "flag": 0}   |
# |{"name": "John", "surname": "Johnson", "amount": 723.39, "delta_t": 3.12, "flag": 0}|
# |{"name": "John", "surname": "Jones", "amount": 729.44, "delta_t": 7.51, "flag": 0}  |
# |{"name": "Alice", "surname": "Jones", "amount": 835.24, "delta_t": 8.41, "flag": 0} |
# |{"name": "Andy", "surname": "Johnson", "amount": 321.01, "delta_t": 0.85, "flag": 0}|
# |{"name": "Jill", "surname": "Millers", "amount": 502.07, "delta_t": 6.18, "flag": 0}|
# |{"name": "Alice", "surname": "Darby", "amount": 395.53, "delta_t": 2.36, "flag": 0} |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 125
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Alice", "surname": "Darby", "amount": 217.29, "delta_t": 6.07, "flag": 0}  |
# |{"name": "Joe", "surname": "Darby", "amount": 380.14, "delta_t": 7.52, "flag": 0}    |
# |{"name": "Andy", "surname": "Jones", "amount": 682.01, "delta_t": 2.88, "flag": 1}   |
# |{"name": "Jill", "surname": "Johnson", "amount": 80.45, "delta_t": 4.36, "flag": 0}  |
# |{"name": "Jill", "surname": "Jones", "amount": 932.52, "delta_t": 5.23, "flag": 0}   |
# |{"name": "Alice", "surname": "Millers", "amount": 148.46, "delta_t": 9.11, "flag": 0}|
# |{"name": "John", "surname": "Smith", "amount": 347.86, "delta_t": 5.57, "flag": 0}   |
# |{"name": "Joe", "surname": "Millers", "amount": 607.67, "delta_t": 4.52, "flag": 1}  |
# |{"name": "Alice", "surname": "Smith", "amount": 236.09, "delta_t": 6.46, "flag": 1}  |
# |{"name": "Joe", "surname": "Smith", "amount": 763.17, "delta_t": 3.51, "flag": 0}    |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 126
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "John", "surname": "Johnson", "amount": 962.12, "delta_t": 4.05, "flag": 0}|
# |{"name": "Jill", "surname": "Darby", "amount": 740.55, "delta_t": 0.99, "flag": 0}  |
# |{"name": "Jill", "surname": "Smith", "amount": 357.09, "delta_t": 8.38, "flag": 0}  |
# |{"name": "Alice", "surname": "Smith", "amount": 749.86, "delta_t": 4.41, "flag": 1} |
# |{"name": "Jill", "surname": "Jones", "amount": 390.65, "delta_t": 8.35, "flag": 0}  |
# |{"name": "Alice", "surname": "Darby", "amount": 409.93, "delta_t": 6.2, "flag": 0}  |
# |{"name": "Andy", "surname": "Smith", "amount": 940.22, "delta_t": 2.18, "flag": 0}  |
# |{"name": "John", "surname": "Millers", "amount": 229.63, "delta_t": 1.29, "flag": 0}|
# |{"name": "John", "surname": "Millers", "amount": 234.75, "delta_t": 8.21, "flag": 0}|
# |{"name": "Jill", "surname": "Millers", "amount": 834.17, "delta_t": 4.16, "flag": 1}|
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 127
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Jill", "surname": "Darby", "amount": 782.89, "delta_t": 0.42, "flag": 0}  |
# |{"name": "Andy", "surname": "Darby", "amount": 390.89, "delta_t": 5.78, "flag": 0}  |
# |{"name": "Joe", "surname": "Millers", "amount": 410.0, "delta_t": 8.33, "flag": 0}  |
# |{"name": "John", "surname": "Millers", "amount": 331.74, "delta_t": 9.56, "flag": 0}|
# |{"name": "Jill", "surname": "Jones", "amount": 972.02, "delta_t": 6.97, "flag": 0}  |
# |{"name": "Alice", "surname": "Smith", "amount": 108.15, "delta_t": 4.61, "flag": 1} |
# |{"name": "John", "surname": "Johnson", "amount": 624.34, "delta_t": 3.98, "flag": 0}|
# |{"name": "Joe", "surname": "Millers", "amount": 554.89, "delta_t": 7.51, "flag": 0} |
# |{"name": "Joe", "surname": "Darby", "amount": 496.51, "delta_t": 0.82, "flag": 1}   |
# |{"name": "John", "surname": "Darby", "amount": 563.98, "delta_t": 2.01, "flag": 0}  |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 128
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "John", "surname": "Darby", "amount": 649.89, "delta_t": 8.82, "flag": 0}   |
# |{"name": "Alice", "surname": "Johnson", "amount": 215.75, "delta_t": 1.66, "flag": 1}|
# |{"name": "Andy", "surname": "Darby", "amount": 82.45, "delta_t": 0.17, "flag": 0}    |
# |{"name": "Joe", "surname": "Johnson", "amount": 937.1, "delta_t": 7.93, "flag": 1}   |
# |{"name": "Joe", "surname": "Johnson", "amount": 512.5, "delta_t": 8.96, "flag": 1}   |
# |{"name": "Jill", "surname": "Johnson", "amount": 653.49, "delta_t": 4.19, "flag": 0} |
# |{"name": "Andy", "surname": "Darby", "amount": 886.33, "delta_t": 3.05, "flag": 0}   |
# |{"name": "Andy", "surname": "Darby", "amount": 71.36, "delta_t": 5.33, "flag": 0}    |
# |{"name": "Jill", "surname": "Darby", "amount": 403.92, "delta_t": 6.89, "flag": 1}   |
# |{"name": "Alice", "surname": "Jones", "amount": 89.2, "delta_t": 2.94, "flag": 0}    |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 129
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Andy", "surname": "Johnson", "amount": 954.71, "delta_t": 6.39, "flag": 1} |
# |{"name": "John", "surname": "Millers", "amount": 922.19, "delta_t": 7.27, "flag": 0} |
# |{"name": "Joe", "surname": "Millers", "amount": 412.66, "delta_t": 9.09, "flag": 0}  |
# |{"name": "Andy", "surname": "Johnson", "amount": 604.99, "delta_t": 8.37, "flag": 0} |
# |{"name": "Alice", "surname": "Johnson", "amount": 299.24, "delta_t": 3.78, "flag": 0}|
# |{"name": "Joe", "surname": "Smith", "amount": 487.16, "delta_t": 6.8, "flag": 1}     |
# |{"name": "Joe", "surname": "Darby", "amount": 597.48, "delta_t": 8.18, "flag": 0}    |
# |{"name": "Joe", "surname": "Darby", "amount": 575.96, "delta_t": 3.48, "flag": 0}    |
# |{"name": "Jill", "surname": "Smith", "amount": 109.26, "delta_t": 2.02, "flag": 0}   |
# |{"name": "Jill", "surname": "Jones", "amount": 850.77, "delta_t": 0.32, "flag": 0}   |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 130
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Jill", "surname": "Jones", "amount": 963.93, "delta_t": 5.24, "flag": 0}  |
# |{"name": "Andy", "surname": "Millers", "amount": 436.63, "delta_t": 4.02, "flag": 0}|
# |{"name": "Andy", "surname": "Millers", "amount": 911.65, "delta_t": 7.59, "flag": 0}|
# |{"name": "Jill", "surname": "Jones", "amount": 328.6, "delta_t": 3.61, "flag": 0}   |
# |{"name": "Alice", "surname": "Johnson", "amount": 234.8, "delta_t": 6.78, "flag": 0}|
# |{"name": "Alice", "surname": "Darby", "amount": 531.31, "delta_t": 8.19, "flag": 1} |
# |{"name": "Joe", "surname": "Johnson", "amount": 382.03, "delta_t": 8.63, "flag": 0} |
# |{"name": "Alice", "surname": "Smith", "amount": 816.2, "delta_t": 2.97, "flag": 0}  |
# |{"name": "John", "surname": "Johnson", "amount": 36.73, "delta_t": 5.44, "flag": 1} |
# |{"name": "John", "surname": "Johnson", "amount": 155.03, "delta_t": 7.56, "flag": 1}|
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 131
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Jill", "surname": "Millers", "amount": 964.26, "delta_t": 0.33, "flag": 0} |
# |{"name": "Alice", "surname": "Johnson", "amount": 874.12, "delta_t": 3.42, "flag": 0}|
# |{"name": "John", "surname": "Darby", "amount": 638.33, "delta_t": 4.54, "flag": 0}   |
# |{"name": "Alice", "surname": "Johnson", "amount": 459.23, "delta_t": 7.42, "flag": 0}|
# |{"name": "Alice", "surname": "Darby", "amount": 385.95, "delta_t": 7.55, "flag": 0}  |
# |{"name": "Alice", "surname": "Darby", "amount": 916.68, "delta_t": 5.32, "flag": 0}  |
# |{"name": "John", "surname": "Millers", "amount": 704.63, "delta_t": 7.04, "flag": 1} |
# |{"name": "John", "surname": "Darby", "amount": 206.83, "delta_t": 5.9, "flag": 0}    |
# |{"name": "Andy", "surname": "Darby", "amount": 377.9, "delta_t": 6.55, "flag": 0}    |
# |{"name": "Jill", "surname": "Smith", "amount": 143.78, "delta_t": 7.72, "flag": 0}   |
# +-------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 132
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Alice", "surname": "Jones", "amount": 354.62, "delta_t": 3.27, "flag": 0} |
# |{"name": "Jill", "surname": "Smith", "amount": 167.77, "delta_t": 4.33, "flag": 0}  |
# |{"name": "Alice", "surname": "Jones", "amount": 709.19, "delta_t": 6.7, "flag": 0}  |
# |{"name": "Joe", "surname": "Jones", "amount": 256.35, "delta_t": 2.35, "flag": 0}   |
# |{"name": "John", "surname": "Darby", "amount": 673.88, "delta_t": 3.83, "flag": 0}  |
# |{"name": "John", "surname": "Smith", "amount": 0.24, "delta_t": 7.93, "flag": 0}    |
# |{"name": "Alice", "surname": "Darby", "amount": 205.51, "delta_t": 7.01, "flag": 0} |
# |{"name": "John", "surname": "Johnson", "amount": 396.6, "delta_t": 5.47, "flag": 0} |
# |{"name": "Jill", "surname": "Millers", "amount": 554.11, "delta_t": 5.07, "flag": 1}|
# |{"name": "Joe", "surname": "Millers", "amount": 413.17, "delta_t": 2.35, "flag": 0} |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 133
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Alice", "surname": "Jones", "amount": 643.94, "delta_t": 3.39, "flag": 0} |
# |{"name": "Joe", "surname": "Millers", "amount": 977.53, "delta_t": 9.7, "flag": 0}  |
# |{"name": "Jill", "surname": "Smith", "amount": 754.04, "delta_t": 3.61, "flag": 0}  |
# |{"name": "Andy", "surname": "Smith", "amount": 958.88, "delta_t": 8.21, "flag": 1}  |
# |{"name": "Andy", "surname": "Millers", "amount": 258.02, "delta_t": 6.04, "flag": 0}|
# |{"name": "Joe", "surname": "Millers", "amount": 959.81, "delta_t": 8.07, "flag": 0} |
# |{"name": "Joe", "surname": "Smith", "amount": 75.94, "delta_t": 7.92, "flag": 0}    |
# |{"name": "Jill", "surname": "Darby", "amount": 232.55, "delta_t": 9.75, "flag": 0}  |
# |{"name": "John", "surname": "Jones", "amount": 434.37, "delta_t": 6.18, "flag": 0}  |
# |{"name": "Joe", "surname": "Millers", "amount": 253.91, "delta_t": 2.31, "flag": 0} |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 134
# -------------------------------------------
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Joe", "surname": "Millers", "amount": 691.02, "delta_t": 4.95, "flag": 1} |
# |{"name": "Andy", "surname": "Smith", "amount": 508.1, "delta_t": 7.44, "flag": 0}   |
# |{"name": "Joe", "surname": "Darby", "amount": 546.1, "delta_t": 7.47, "flag": 0}    |
# |{"name": "Jill", "surname": "Jones", "amount": 327.89, "delta_t": 0.17, "flag": 0}  |
# |{"name": "John", "surname": "Darby", "amount": 775.55, "delta_t": 7.29, "flag": 1}  |
# |{"name": "Jill", "surname": "Darby", "amount": 173.87, "delta_t": 6.11, "flag": 1}  |
# |{"name": "John", "surname": "Darby", "amount": 817.89, "delta_t": 7.54, "flag": 1}  |
# |{"name": "Jill", "surname": "Darby", "amount": 337.13, "delta_t": 9.74, "flag": 0}  |
# |{"name": "Jill", "surname": "Johnson", "amount": 885.11, "delta_t": 6.77, "flag": 0}|
# |{"name": "John", "surname": "Smith", "amount": 22.95, "delta_t": 8.29, "flag": 1}   |
# +------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 135
# -------------------------------------------
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |{"name": "Andy", "surname": "Jones", "amount": 900.6, "delta_t": 2.39, "flag": 0}    |
# |{"name": "Alice", "surname": "Johnson", "amount": 921.81, "delta_t": 9.89, "flag": 0}|
# |{"name": "John", "surname": "Smith", "amount": 444.31, "delta_t": 6.84, "flag": 0}   |
# |{"name": "John", "surname": "Jones", "amount": 748.67, "delta_t": 2.67, "flag": 0}   |
# |{"name": "John", "surname": "Darby", "amount": 295.66, "delta_t": 9.02, "flag": 1}   |
# |{"name": "Alice", "surname": "Smith", "amount": 639.89, "delta_t": 7.74, "flag": 0}  |
# |{"name": "Alice", "surname": "Darby", "amount": 686.43, "delta_t": 9.44, "flag": 0}  |
# |{"name": "John", "surname": "Johnson", "amount": 980.7, "delta_t": 2.24, "flag": 0}  |
# |{"name": "Alice", "surname": "Millers", "amount": 314.67, "delta_t": 5.87, "flag": 1}|
# |{"name": "Joe", "surname": "Smith", "amount": 448.78, "delta_t": 7.32, "flag": 1}    |
# +-------------------------------------------------------------------------------------+

# %% [markdown]
# Run this cell to stop the streaming query execution

# %%
query.stop()

# %% [markdown]
# ## Example of streaming query: data parsing
#
# Data received from the TCP source is seen as a `string` by the spark application
#
# We first must develop an application parsing the string and creating a column for each `json` field in order to start processing the dataset using the DataFrame API functionalities
#
# It can be useful to start with a set of test data, to develop this query.
#
# **The same Spark code (transformations/actions) used for processing a "static" DataFrame can be used for the streaming context!**

# %%
# dummy data for testing purposes
testData = [
    '{"name": "Jill", "surname": "Millers", "amount": 736.56, "delta_t": 7.78, "flag": 0}',
    '{"name": "John", "surname": "Johnson", "amount": 986.47, "delta_t": 3.9, "flag": 0}',
    '{"name": "John", "surname": "Jones", "amount": 249.9, "delta_t": 0.62, "flag": 1}',
    '{"name": "Andy", "surname": "Jones", "amount": 950.95, "delta_t": 6.02, "flag": 0}',
    '{"name": "Jill", "surname": "Millers", "amount": 724.32, "delta_t": 9.19, "flag": 0}',
    '{"name": "John", "surname": "Johnson", "amount": 850.07, "delta_t": 7.33, "flag": 1}',
    '{"name": "Andy", "surname": "Smith", "amount": 557.48, "delta_t": 9.64, "flag": 0}',
    '{"name": "Alice", "surname": "Darby", "amount": 424.75, "delta_t": 7.76, "flag": 0}'
]

# %% [markdown]
# Create a Spark DataFrame by importing the `testData`.
#
# It can be useful to investigate the `pyspark.sql.types` to check whether there is any helping function that could be used for this purpose.

# %%
from pyspark.sql.types import StringType

# create a spark dataframe from testdata
testDf = spark.createDataFrame(testData, StringType())

# %%
# show the dataframe content
testDf.show(n=5, truncate=False)
# Out:
# [Stage 154:============================>                            (1 + 1) / 2]
# +------------------------------------------------------------------------------------+
# |value                                                                               |
# +------------------------------------------------------------------------------------+
# |{"name": "Jill", "surname": "Millers", "amount": 736.56, "delta_t": 7.78, "flag": 0}|
# |{"name": "John", "surname": "Johnson", "amount": 986.47, "delta_t": 3.9, "flag": 0} |
# |{"name": "John", "surname": "Jones", "amount": 249.9, "delta_t": 0.62, "flag": 1}   |
# |{"name": "Andy", "surname": "Jones", "amount": 950.95, "delta_t": 6.02, "flag": 0}  |
# |{"name": "Jill", "surname": "Millers", "amount": 724.32, "delta_t": 9.19, "flag": 0}|
# +------------------------------------------------------------------------------------+
# only showing top 5 rows

# %% [markdown]
# Data are now in the same format as the one received by the socket data source.
#
# The function `from_json` can be used to parse a `json` string with a given schema. Aa always, have a look at the [documentation](https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.functions.from_json.html?highlight=from_json) before using it.
#
# Start by defining a schema for our data.

# %%
import pyspark.sql.functions as f
from pyspark.sql.types import StructField, StructType, StringType, DoubleType, IntegerType

# create the schema
schema = StructType(
    [
        StructField("name", StringType()),
        StructField("surname", StringType()),
        StructField("amount", DoubleType()),
        StructField("delta_t", DoubleType()),
        StructField("flag", IntegerType())
    ]
)

# %% [markdown]
# And create a "parsed" DataFrame to verify if our schema is properly addressing the data types.

# %%
# parse the dataframe and show its structure
parsedTestDf = testDf.select(f.from_json('value', schema=schema))

parsedTestDf.printSchema()
# Out:
# root
#  |-- from_json(value): struct (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- surname: string (nullable = true)
#  |    |-- amount: double (nullable = true)
#  |    |-- delta_t: double (nullable = true)
#  |    |-- flag: integer (nullable = true)

# %% [markdown]
# The structure obtained using `from_json` is actually inherently nested...
# The `json` messages were correctly parsed, but a nested DataFrame is returned, which should be flattened before being able to use it as a "plain DataFrame".
#
#
# As discussed in the DataFrame notebook, this can be easily solved in a variety of ways, for instance by selecting the columns we are interested in using from now on...
#
#
# As an example, the `name` and `surname` columns could be selected.

# %%
# show values from the parsedTestDf
parsedTestDf.show(n=5, truncate=False)
# Out:
# +--------------------------------+
# |from_json(value)                |
# +--------------------------------+
# |{Jill, Millers, 736.56, 7.78, 0}|
# |{John, Johnson, 986.47, 3.9, 0} |
# |{John, Jones, 249.9, 0.62, 1}   |
# |{Andy, Jones, 950.95, 6.02, 0}  |
# |{Jill, Millers, 724.32, 9.19, 0}|
# +--------------------------------+
# only showing top 5 rows

# %%
# re-create the parsedTestDf by 
# - aliasing the values produced by from_json as `data`
# - selecting the columns `data.name` and `data.surname`
parsedTestDf = (
    testDf
    .select(f.from_json('value', schema=schema).alias('data'))
    .select(f.col('data.name'), f.col('data.surname')) 
)

# NB: data.* will select all the columns, as in plain SQL

# %%
# print the new schema
parsedTestDf.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- surname: string (nullable = true)

# %%
# and show the new content
parsedTestDf.show(5)
# Out:
# +----+-------+
# |name|surname|
# +----+-------+
# |Jill|Millers|
# |John|Johnson|
# |John|  Jones|
# |Andy|  Jones|
# |Jill|Millers|
# +----+-------+
# only showing top 5 rows

# %% [markdown]
# ### From static to streaming queries
#
# Now that we have developed a way to extract and interpret the data using a static example, we can reuse the very same code for the streaming query, by simply "chaining" the application to the source and directing its results to the sink.
#
# **NB**: Remember to restart the producer application before starting the queries.

# %% [markdown]
# Re-create the "raw" DataFrame connecting the Spark Structured Streaming Context to the input TCP socket.
#
# **Do not `start` the stream just yet!**

# %%
# the hostname and port number
hostname = "spark-master"
portnumber = 5555

# recreate the streaming raw dataframe
rawMessagesDf = (
    spark
    .readStream
    .format("socket")
    .option("host", hostname)
    .option("port", portnumber)
    .load()
)
# Out:
# 25/05/15 07:41:26 WARN TextSocketSourceProvider: The socket source should not be used for production applications! It does not support recovery.

# %% [markdown]
# Starting from the streaming DataFrame, issue the appropriate transformations to interpret its `json` format, and prepare a new parsed DataFrame including all (`*`) the columns.

# %%
# parse the json lines using the previous schema
# select all columns 
parsedDf = (
    rawMessagesDf.select(f.from_json('value', schema=schema).alias('data'))
    .select(f.col('data.*')) 
)

# %% [markdown]
# Start the application as done previously, with:
# - `outputMode=update`
# - `format=console`
#
# Choose the trigger as you prefer.
# A suggestion is to keep it simple, and use a time-based trigger of 2 seconds.

# %%
query = (
    parsedDf
    .writeStream
    .outputMode('update')
    .format('console')
    .trigger(processingTime='2 seconds')
    .option("truncate", False)
    .start()
)
# Out:
# 25/05/15 07:41:38 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-44fc53dd-8f39-4b23-b7c1-31cc30a4f443. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +----+-------+------+-------+----+
# |name|surname|amount|delta_t|flag|
# +----+-------+------+-------+----+
# +----+-------+------+-------+----+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +-----+-------+------+-------+----+
# |name |surname|amount|delta_t|flag|
# +-----+-------+------+-------+----+
# |Andy |Johnson|302.7 |6.21   |0   |
# |Andy |Jones  |169.11|0.66   |1   |
# |John |Smith  |558.68|0.47   |0   |
# |Joe  |Darby  |607.86|0.93   |0   |
# |Joe  |Johnson|830.39|2.61   |0   |
# |Andy |Smith  |944.48|0.29   |0   |
# |Alice|Darby  |394.75|2.68   |0   |
# +-----+-------+------+-------+----+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +-----+-------+------+-------+----+
# |name |surname|amount|delta_t|flag|
# +-----+-------+------+-------+----+
# |Andy |Smith  |79.83 |8.48   |0   |
# |Alice|Darby  |332.11|1.45   |0   |
# |Joe  |Jones  |901.05|2.76   |0   |
# |Joe  |Smith  |0.14  |2.53   |0   |
# |John |Millers|318.19|5.97   |0   |
# |Andy |Johnson|885.24|2.17   |0   |
# |John |Millers|961.41|9.88   |0   |
# |Jill |Smith  |583.69|0.93   |0   |
# |Jill |Smith  |944.81|9.43   |0   |
# |John |Johnson|474.45|6.34   |0   |
# +-----+-------+------+-------+----+
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +-----+-------+------+-------+----+
# |name |surname|amount|delta_t|flag|
# +-----+-------+------+-------+----+
# |Jill |Jones  |217.94|5.61   |0   |
# |Jill |Darby  |29.83 |3.4    |0   |
# |John |Jones  |718.06|5.03   |0   |
# |Alice|Darby  |428.37|4.28   |0   |
# |Alice|Millers|943.74|7.85   |0   |
# |John |Smith  |425.66|0.48   |0   |
# |Alice|Darby  |1.26  |7.42   |0   |
# |Joe  |Millers|785.09|4.61   |0   |
# |Andy |Smith  |971.45|5.18   |1   |
# |Joe  |Johnson|343.06|0.19   |0   |
# +-----+-------+------+-------+----+
#
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +-----+-------+------+-------+----+
# |name |surname|amount|delta_t|flag|
# +-----+-------+------+-------+----+
# |Joe  |Millers|267.79|6.14   |0   |
# |Jill |Johnson|921.85|6.09   |1   |
# |Alice|Jones  |193.43|5.94   |0   |
# |Joe  |Jones  |118.92|6.27   |0   |
# |John |Johnson|875.51|8.25   |1   |
# |Jill |Johnson|974.46|0.78   |0   |
# |Jill |Jones  |872.02|2.28   |0   |
# |John |Johnson|301.08|3.02   |0   |
# |Jill |Smith  |603.6 |8.97   |0   |
# |Joe  |Jones  |863.61|1.22   |0   |
# +-----+-------+------+-------+----+
#
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +-----+-------+------+-------+----+
# |name |surname|amount|delta_t|flag|
# +-----+-------+------+-------+----+
# |Alice|Smith  |452.55|4.9    |0   |
# |Jill |Darby  |298.57|8.6    |0   |
# |Alice|Millers|640.71|4.09   |1   |
# |Joe  |Johnson|938.02|4.4    |0   |
# |Alice|Millers|90.98 |1.28   |0   |
# |Andy |Darby  |754.52|8.57   |0   |
# |Andy |Johnson|629.05|9.6    |0   |
# |Alice|Johnson|921.12|5.86   |0   |
# |Jill |Johnson|480.78|3.27   |1   |
# |Andy |Johnson|925.62|0.45   |1   |
# +-----+-------+------+-------+----+

# %%
query.stop()

# %% [markdown]
# ### Process each bach to identify possibly fraudolent transactions
#
# 1. compute the _number of flagged transactions per batch per user_ (create a unique `userID` field as the combination of _FirstLastname_ to idenfity individual users)
# 2. identify all the "suspicios" transactions per user: all users with more than one flagged transaction per batch will be assigned a `isFraud` boolean variable
# 3. format the resulting `userID` and `isFraud` information in a DataFrame to mimick a "live-report" of the suspicious transactions

# %%
# the hostname and port number
hostname = "spark-master"
portnumber = 5555

rawMessagesDf = ( spark
    .readStream
    .format("socket")
    .option("host", hostname)
    .option("port", portnumber)
    .load()
)
# Out:
# 25/05/15 07:54:22 WARN TextSocketSourceProvider: The socket source should not be used for production applications! It does not support recovery.

# %%
# parse json lines, use a schema
parsedDf = (
    rawMessagesDf.select(f.from_json('value', schema=schema).alias('data'))
    .select(f.col('data.*')) 
)

# %%
# find number of transactions for each user when flag = 1 
#    declare a new column to create a unique user identifier 
#    this can be easily done by concatenating first- and last-name fields
#    check the concat function from pyspark.sql.functions 
numTransactions = (
    parsedDf.filter('flag==1')
    .withColumn('id', f.concat(f.col('name'),f.col('surname')))
    .groupBy('id')
    .count() 
)

# %%
# find suspicious transactions
#    filter only users with more than one transaction per batch
#    create a "fraud" column with a value of 1 for the selected users (check the lit function)
#    from the dataframe, project the unique id, fraud flag and number of transaction columns
susTransactions = (
    numTransactions.filter('count>1')
    .withColumn('fraud', f.lit(1))
    .select(f.col('id').alias('UniqueID'), f.col('fraud'), f.col('count').alias('nFraudTransactions'))
)

# %%
# this line is a trick to force Spark to use a small number of partitions (4 in this example)  default is 256 (efficient for large datasets, but not in this case)
spark.conf.set("spark.sql.shuffle.partitions", 4)

# %%
query = (
    susTransactions
    .writeStream
    .outputMode('update')
    .format('console')
    .trigger(processingTime='5 seconds')
    .option("truncate", False)
    .start()
)
# Out:
# 25/05/15 08:12:09 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-e10c09a0-13a8-4ba2-a4a9-a6a5bb3ba86a. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 25/05/15 08:12:15 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5172 milliseconds
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +--------+-----+------------------+
# |UniqueID|fraud|nFraudTransactions|
# +--------+-----+------------------+
# +--------+-----+------------------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +---------+-----+------------------+
# |UniqueID |fraud|nFraudTransactions|
# +---------+-----+------------------+
# |JohnSmith|1    |2                 |
# +---------+-----+------------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |JillMillers|1    |2                 |
# +-----------+-----+------------------+
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +--------+-----+------------------+
# |UniqueID|fraud|nFraudTransactions|
# +--------+-----+------------------+
# |JoeSmith|1    |2                 |
# +--------+-----+------------------+
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +----------+-----+------------------+
# |UniqueID  |fraud|nFraudTransactions|
# +----------+-----+------------------+
# |JoeJohnson|1    |2                 |
# +----------+-----+------------------+
#
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +------------+-----+------------------+
# |UniqueID    |fraud|nFraudTransactions|
# +------------+-----+------------------+
# |JohnSmith   |1    |3                 |
# |JohnJohnson |1    |2                 |
# |AliceMillers|1    |2                 |
# |JillDarby   |1    |2                 |
# +------------+-----+------------------+
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |JoeDarby   |1    |2                 |
# |AndyJohnson|1    |2                 |
# |JohnDarby  |1    |2                 |
# +-----------+-----+------------------+
# -------------------------------------------
# Batch: 7
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |JohnJohnson|1    |3                 |
# +-----------+-----+------------------+
# -------------------------------------------
# Batch: 8
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |JillJones  |1    |2                 |
# |JohnSmith  |1    |4                 |
# |JillSmith  |1    |3                 |
# |AndyJohnson|1    |3                 |
# |JoeDarby   |1    |3                 |
# |AndySmith  |1    |2                 |
# |JoeJones   |1    |2                 |
# +-----------+-----+------------------+
#
# -------------------------------------------
# Batch: 9
# -------------------------------------------
# +------------+-----+------------------+
# |UniqueID    |fraud|nFraudTransactions|
# +------------+-----+------------------+
# |AliceJones  |1    |2                 |
# |JillJones   |1    |3                 |
# |JohnJohnson |1    |4                 |
# |AliceMillers|1    |3                 |
# +------------+-----+------------------+
#
# -------------------------------------------
# Batch: 10
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |JohnMillers|1    |2                 |
# |JoeSmith   |1    |3                 |
# |AndySmith  |1    |3                 |
# +-----------+-----+------------------+
#
# -------------------------------------------
# Batch: 11
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |JillJones  |1    |4                 |
# |JillSmith  |1    |4                 |
# |AndyDarby  |1    |2                 |
# |JoeSmith   |1    |5                 |
# |JohnJohnson|1    |5                 |
# |JillDarby  |1    |3                 |
# +-----------+-----+------------------+
#
# -------------------------------------------
# Batch: 12
# -------------------------------------------
# +----------+-----+------------------+
# |UniqueID  |fraud|nFraudTransactions|
# +----------+-----+------------------+
# |JillSmith |1    |5                 |
# |AliceJones|1    |3                 |
# |AliceSmith|1    |2                 |
# +----------+-----+------------------+
#
# -------------------------------------------
# Batch: 13
# -------------------------------------------
# +------------+-----+------------------+
# |UniqueID    |fraud|nFraudTransactions|
# +------------+-----+------------------+
# |JillJones   |1    |5                 |
# |JohnSmith   |1    |5                 |
# |AliceMillers|1    |4                 |
# |JoeJones    |1    |3                 |
# +------------+-----+------------------+
#
# -------------------------------------------
# Batch: 14
# -------------------------------------------
# +------------+-----+------------------+
# |UniqueID    |fraud|nFraudTransactions|
# +------------+-----+------------------+
# |AliceJohnson|1    |2                 |
# |AndySmith   |1    |4                 |
# |JoeSmith    |1    |7                 |
# +------------+-----+------------------+
#
# -------------------------------------------
# Batch: 15
# -------------------------------------------
# +------------+-----+------------------+
# |UniqueID    |fraud|nFraudTransactions|
# +------------+-----+------------------+
# |AndyJones   |1    |2                 |
# |JillMillers |1    |3                 |
# |AliceJohnson|1    |3                 |
# |AndyDarby   |1    |3                 |
# +------------+-----+------------------+
#
# -------------------------------------------
# Batch: 16
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |AndyJohnson|1    |4                 |
# |JoeDarby   |1    |4                 |
# |AndyJones  |1    |3                 |
# |JohnJohnson|1    |6                 |
# |JillMillers|1    |4                 |
# |JoeMillers |1    |2                 |
# +-----------+-----+------------------+
#
# -------------------------------------------
# Batch: 17
# -------------------------------------------
# +----------+-----+------------------+
# |UniqueID  |fraud|nFraudTransactions|
# +----------+-----+------------------+
# |JohnJones |1    |3                 |
# |AliceDarby|1    |2                 |
# +----------+-----+------------------+
#
# -------------------------------------------
# Batch: 18
# -------------------------------------------
# +------------+-----+------------------+
# |UniqueID    |fraud|nFraudTransactions|
# +------------+-----+------------------+
# |JohnSmith   |1    |6                 |
# |JoeJohnson  |1    |3                 |
# |JohnMillers |1    |3                 |
# |AndyJones   |1    |4                 |
# |AndySmith   |1    |6                 |
# |AliceMillers|1    |5                 |
# |AliceSmith  |1    |3                 |
# |AndyMillers |1    |2                 |
# +------------+-----+------------------+
#
# -------------------------------------------
# Batch: 19
# -------------------------------------------
# +------------+-----+------------------+
# |UniqueID    |fraud|nFraudTransactions|
# +------------+-----+------------------+
# |JohnMillers |1    |4                 |
# |JohnSmith   |1    |7                 |
# |AliceMillers|1    |6                 |
# |JoeJones    |1    |4                 |
# |JillDarby   |1    |4                 |
# +------------+-----+------------------+
#
# -------------------------------------------
# Batch: 20
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |JohnSmith  |1    |9                 |
# |AndyJohnson|1    |5                 |
# |JoeDarby   |1    |5                 |
# |JillSmith  |1    |6                 |
# |JohnDarby  |1    |3                 |
# |JoeSmith   |1    |8                 |
# |AliceSmith |1    |4                 |
# |JoeJones   |1    |5                 |
# +-----------+-----+------------------+
#
# -------------------------------------------
# Batch: 21
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |JohnMillers|1    |5                 |
# |JillJones  |1    |6                 |
# |JoeMillers |1    |3                 |
# |JohnJones  |1    |4                 |
# +-----------+-----+------------------+
#
# -------------------------------------------
# Batch: 22
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |JoeDarby   |1    |6                 |
# |AndyJohnson|1    |6                 |
# |AliceJones |1    |4                 |
# |JoeSmith   |1    |9                 |
# |AliceSmith |1    |5                 |
# +-----------+-----+------------------+
#
# -------------------------------------------
# Batch: 23
# -------------------------------------------
# +----------+-----+------------------+
# |UniqueID  |fraud|nFraudTransactions|
# +----------+-----+------------------+
# |AliceDarby|1    |3                 |
# +----------+-----+------------------+
#
# -------------------------------------------
# Batch: 24
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |JillJones  |1    |7                 |
# |JillJohnson|1    |2                 |
# |JoeJones   |1    |6                 |
# +-----------+-----+------------------+
#
# -------------------------------------------
# Batch: 25
# -------------------------------------------
# +------------+-----+------------------+
# |UniqueID    |fraud|nFraudTransactions|
# +------------+-----+------------------+
# |JohnSmith   |1    |10                |
# |JoeDarby    |1    |7                 |
# |JillJohnson |1    |4                 |
# |AndyJones   |1    |5                 |
# |AliceJohnson|1    |4                 |
# +------------+-----+------------------+
#
# -------------------------------------------
# Batch: 26
# -------------------------------------------
# +------------+-----+------------------+
# |UniqueID    |fraud|nFraudTransactions|
# +------------+-----+------------------+
# |JohnMillers |1    |6                 |
# |JillSmith   |1    |7                 |
# |AliceJohnson|1    |6                 |
# |JoeJones    |1    |7                 |
# +------------+-----+------------------+
#
# -------------------------------------------
# Batch: 27
# -------------------------------------------
# +----------+-----+------------------+
# |UniqueID  |fraud|nFraudTransactions|
# +----------+-----+------------------+
# |JohnDarby |1    |4                 |
# |JoeSmith  |1    |10                |
# |AndySmith |1    |7                 |
# |JillDarby |1    |5                 |
# |AliceDarby|1    |4                 |
# +----------+-----+------------------+
#
# -------------------------------------------
# Batch: 28
# -------------------------------------------
# +----------+-----+------------------+
# |UniqueID  |fraud|nFraudTransactions|
# +----------+-----+------------------+
# |JillSmith |1    |8                 |
# |AndyJones |1    |6                 |
# |JoeSmith  |1    |11                |
# |AliceSmith|1    |6                 |
# +----------+-----+------------------+
#
# -------------------------------------------
# Batch: 29
# -------------------------------------------
# +------------+-----+------------------+
# |UniqueID    |fraud|nFraudTransactions|
# +------------+-----+------------------+
# |JillMillers |1    |5                 |
# |AliceMillers|1    |7                 |
# |JillDarby   |1    |6                 |
# |AndyMillers |1    |3                 |
# |JoeJones    |1    |8                 |
# +------------+-----+------------------+
#
# -------------------------------------------
# Batch: 30
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |AliceJones |1    |5                 |
# |JohnSmith  |1    |11                |
# |JoeJohnson |1    |4                 |
# |JillJones  |1    |8                 |
# |AndyJones  |1    |7                 |
# |AndySmith  |1    |8                 |
# |JillMillers|1    |6                 |
# |JoeMillers |1    |4                 |
# +-----------+-----+------------------+
#
# -------------------------------------------
# Batch: 31
# -------------------------------------------
# +------------+-----+------------------+
# |UniqueID    |fraud|nFraudTransactions|
# +------------+-----+------------------+
# |JoeJohnson  |1    |5                 |
# |JoeDarby    |1    |8                 |
# |JillMillers |1    |7                 |
# |AliceMillers|1    |8                 |
# |JohnJohnson |1    |7                 |
# +------------+-----+------------------+
#
# -------------------------------------------
# Batch: 32
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |AndyJohnson|1    |7                 |
# |JoeSmith   |1    |12                |
# |JohnDarby  |1    |5                 |
# |AndySmith  |1    |9                 |
# |AliceDarby |1    |5                 |
# |AndyMillers|1    |4                 |
# +-----------+-----+------------------+
#
# -------------------------------------------
# Batch: 33
# -------------------------------------------
# +----------+-----+------------------+
# |UniqueID  |fraud|nFraudTransactions|
# +----------+-----+------------------+
# |JoeDarby  |1    |9                 |
# |AliceJones|1    |6                 |
# |AndyJones |1    |8                 |
# |JohnDarby |1    |8                 |
# |AliceSmith|1    |7                 |
# |JoeMillers|1    |5                 |
# |JillDarby |1    |7                 |
# +----------+-----+------------------+
#
# -------------------------------------------
# Batch: 34
# -------------------------------------------
# +----------+-----+------------------+
# |UniqueID  |fraud|nFraudTransactions|
# +----------+-----+------------------+
# |JohnSmith |1    |12                |
# |JoeSmith  |1    |13                |
# |AliceSmith|1    |9                 |
# |JoeMillers|1    |6                 |
# +----------+-----+------------------+
#
# -------------------------------------------
# Batch: 35
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |AliceJones |1    |7                 |
# |JohnMillers|1    |7                 |
# |AndyJones  |1    |9                 |
# |JohnJohnson|1    |8                 |
# |AndyDarby  |1    |4                 |
# +-----------+-----+------------------+
#
# -------------------------------------------
# Batch: 36
# -------------------------------------------
# +------------+-----+------------------+
# |UniqueID    |fraud|nFraudTransactions|
# +------------+-----+------------------+
# |JillSmith   |1    |9                 |
# |AndyJones   |1    |10                |
# |AliceSmith  |1    |10                |
# |AliceJohnson|1    |7                 |
# |JoeSmith    |1    |14                |
# |JoeMillers  |1    |7                 |
# +------------+-----+------------------+
#
# -------------------------------------------
# Batch: 37
# -------------------------------------------
# +------------+-----+------------------+
# |UniqueID    |fraud|nFraudTransactions|
# +------------+-----+------------------+
# |JoeDarby    |1    |10                |
# |AndyJones   |1    |11                |
# |AliceJohnson|1    |8                 |
# |AndyMillers |1    |5                 |
# |JillDarby   |1    |8                 |
# +------------+-----+------------------+
#
# -------------------------------------------
# Batch: 38
# -------------------------------------------
# +------------+-----+------------------+
# |UniqueID    |fraud|nFraudTransactions|
# +------------+-----+------------------+
# |AndyJohnson |1    |8                 |
# |AliceJones  |1    |8                 |
# |AndyJones   |1    |12                |
# |AliceJohnson|1    |9                 |
# |AndySmith   |1    |10                |
# +------------+-----+------------------+

# %%
query.stop()

# %% [markdown]
# Since this query contains aggregations, output mode can be changed to `complete`.
# In this case, the full set of results is displayed for every batch.

# %%
query = (
    susTransactions
    .writeStream
    .outputMode('complete')
    .format('console')
    .trigger(processingTime='5 seconds')
    .option("truncate", False)
    .start()
)
# Out:
# 25/05/15 08:16:50 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-0626df38-4abb-48a3-8e7e-c3e793359601. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +--------+-----+------------------+
# |UniqueID|fraud|nFraudTransactions|
# +--------+-----+------------------+
# +--------+-----+------------------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +--------+-----+------------------+
# |UniqueID|fraud|nFraudTransactions|
# +--------+-----+------------------+
# +--------+-----+------------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +---------+-----+------------------+
# |UniqueID |fraud|nFraudTransactions|
# +---------+-----+------------------+
# |AndyJones|1    |2                 |
# |JoeSmith |1    |2                 |
# +---------+-----+------------------+
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |AndyJones  |1    |2                 |
# |JoeSmith   |1    |2                 |
# |AndyMillers|1    |2                 |
# +-----------+-----+------------------+
#
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |AndyJones  |1    |2                 |
# |JoeSmith   |1    |2                 |
# |AndyMillers|1    |2                 |
# +-----------+-----+------------------+
#
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |JillSmith  |1    |3                 |
# |AndyJones  |1    |2                 |
# |JillMillers|1    |2                 |
# |JoeSmith   |1    |3                 |
# |JillDarby  |1    |2                 |
# |AndyMillers|1    |2                 |
# +-----------+-----+------------------+
#
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +-----------+-----+------------------+
# |UniqueID   |fraud|nFraudTransactions|
# +-----------+-----+------------------+
# |JillJones  |1    |2                 |
# |JillSmith  |1    |4                 |
# |AndyJones  |1    |2                 |
# |JillMillers|1    |3                 |
# |JohnJohnson|1    |2                 |
# |JoeSmith   |1    |3                 |
# |JillDarby  |1    |2                 |
# |AndyMillers|1    |3                 |
# +-----------+-----+------------------+

# %%
query.stop()

# %% [markdown]
# ## Stop spark worker

# %%
spark.stop()
