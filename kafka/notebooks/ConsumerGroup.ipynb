# %% [markdown]
# # Kafka Consumer group

# %%
# define the list of brokers in the cluster
KAFKA_BOOTSTRAP_SERVERS = ['kafka-broker:9092']

# %%
from kafka import KafkaConsumer

# create `consumer_two` to read from a specific partition
# assign this consumer to a group
consumer_two = KafkaConsumer(bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS,
                             client_id='consumer_two',
                             group_id='my_group',                       # the same group will be used by all consumers
                             auto_offset_reset='earliest',
                             consumer_timeout_ms=10000)

# %%
import json

# subscribe `consumer_two` to the partitioned topic
consumer_two.subscribe(['a_partitioned_topic'])

# %%
# check the partitions assigned to `consumer_two`
consumer_two.assignment()
# Out:
# set()

# %%
# use multiple consumers in parallel (`consumer_two` in this notebook)
for message in consumer_two:
    print(f"{message.partition}[{message.offset}]\t {json.loads(message.value)}")
# Out:
# 1[23]	 {'name': 'Alice', 'surname': 'Millers', 'amount': 663.93, 'delta_t': 2.84, 'flag': 0}
# 1[24]	 {'name': 'Andy', 'surname': 'Millers', 'amount': 132.82, 'delta_t': 1.69, 'flag': 0}
# 1[25]	 {'name': 'Alice', 'surname': 'Jones', 'amount': 593.04, 'delta_t': 5.04, 'flag': 0}
# 1[26]	 {'name': 'Alice', 'surname': 'Johnson', 'amount': 685.13, 'delta_t': 7.55, 'flag': 0}
# 1[27]	 {'name': 'Alice', 'surname': 'Jones', 'amount': 929.37, 'delta_t': 7.05, 'flag': 0}
# 1[28]	 {'name': 'Joe', 'surname': 'Jones', 'amount': 585.02, 'delta_t': 1.64, 'flag': 1}
# 1[29]	 {'name': 'Joe', 'surname': 'Millers', 'amount': 516.68, 'delta_t': 3.3, 'flag': 0}
# 1[30]	 {'name': 'Alice', 'surname': 'Millers', 'amount': 933.89, 'delta_t': 4.28, 'flag': 0}
# 1[31]	 {'name': 'Alice', 'surname': 'Jones', 'amount': 205.08, 'delta_t': 4.31, 'flag': 0}
# 1[32]	 {'name': 'Joe', 'surname': 'Smith', 'amount': 257.08, 'delta_t': 6.35, 'flag': 0}
# 1[33]	 {'name': 'Joe', 'surname': 'Smith', 'amount': 621.0, 'delta_t': 8.74, 'flag': 0}
# 1[34]	 {'name': 'Alice', 'surname': 'Millers', 'amount': 32.77, 'delta_t': 4.84, 'flag': 0}
# 1[35]	 {'name': 'Andy', 'surname': 'Johnson', 'amount': 627.01, 'delta_t': 9.08, 'flag': 0}
# 1[36]	 {'name': 'Andy', 'surname': 'Smith', 'amount': 224.7, 'delta_t': 9.97, 'flag': 0}
# 1[37]	 {'name': 'Joe', 'surname': 'Millers', 'amount': 882.73, 'delta_t': 9.1, 'flag': 0}

# %%
# check the partitions assigned to `consumer_two`
consumer_two.assignment()
# Out:
# {TopicPartition(topic='a_partitioned_topic', partition=1)}
