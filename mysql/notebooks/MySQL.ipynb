# %% [markdown]
# # RDBMS - MySQL
#
# ## 00 - Introduction
#
# Among the Relational DBMSs, the most widely known are Oracle, SQLite, Postgres, MariaDB, and MySQL.
#
# Each one of them is characterized by a different set of "variations" on top of the base SQL language, although usually minor.
#
# We will use **MySQL** to run exercises about Relational DB transactions using the SQL language, as it is *currently* at the top of the list of most widely used RDBMSs.
#
# [DB Engines Ranking Trend](https://db-engines.com/en/ranking_trend/relational+dbms)
#
# [Worldwide Popularity Ranking of Database Management Systems](https://www.statista.com/statistics/809750/worldwide-popularity-ranking-database-management-systems/)
#
# [Stack Overflow 2024 Developer Survey - Most Popular Technologies (Language)](https://survey.stackoverflow.co/2024/technology/#1-programming-scripting-and-markup-languages)
#
# [Stack Overflow 2024 Developer Survey - Most Popular Technologies (Database)](https://survey.stackoverflow.co/2024/technology/#1-databases)

# %% [markdown]
# MySQL programming interfaces exist for many languages, including C, C++, Go, Java, Perl, PHP, Python, etc...
#
# Even simply referring to Python, we can count on several options to connect and interact with the DBs.
#
# Let's explore a couple of them...

# %% [markdown]
# ## 01 - Create a Connection to MySQL
#
# A MySQL server is running within one of your Docker containers.
#
# You can access it using the MySQL server credentials defined in the `docker-compose.yml` file.
#
# By default, a `root` user is created with the following credentials:
# - **Username:** `root`
# - **Password:** `root_pwd`
#
# Additionally, a non-`root` user is created by default with:
# - **Username:** `my_user`
# - **Password:** `my_pwd`

# %% [markdown]
# #### Interactive
#
# To interact with the MySQL server, you can log in interactively to its Docker container.
#
# First, check the `CONTAINER ID` of the container named `mysql_db` by running:
#
# ```bash
# $ docker ps
# ```
#
# Then, initiate an interactive bash session within the container by executing:
#
# ```bash
# $ docker exec -it <YOUR CONTAINER ID> bash
# ```
#
# Once inside the container, you can access the MySQL server as if you were connected to a remote server hosting your databases:
#
# ```bash
# $ mysql -u <EITHER ROOT OR USER> -p
# ```
#
# Replace `<YOUR CONTAINER ID>` with the actual container ID obtained from the `docker ps` command output, and `<EITHER ROOT OR USER>` with either `root` or `my_user`, depending on the user you want to log in as.

# %% [markdown]
# We can then inspect the MySQL server to display all databases by executing the following SQL command:
#
# ```mysql
# SHOW DATABASES;
# ```
#
# **NB**: Remember to end a SQL command with a semicolon `;`.

# %% [markdown]
# #### mysql.connector
#
# A more pythonic way to interact with a MySQL server is by using a dedicated driver such as `mysql.connector`, which is already installed in the Jupyter Notebook container.
#
# This connector offers an interface to establish a connection object to the MySQL server and provides various functionalities for executing transactions and fetching records from databases.
#
# We can start by declaring a connection to our MySQL server.
#
# **NB:** The server is hosted in a different container from the notebook, simulating a connection between two different machines: a client and a server.

# %%
# import the connector
import mysql.connector

# declare a connection to the MySQL server 
# the hostname (or IP) of the server machine should be passed
db = mysql.connector.connect(
  user="root",   
  password="root_pwd",
  host="db", # in this case 'db' is the equivalent of the IP address of the server 
             # or 'localhost' if running mysql locally
)

print(db)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x7f3815ffbe00>

# %% [markdown]
# At this point, a database connection is established.
#
# To interact with the database using Python and `mysql.connector`, we need a "handle" known as a cursor, which must be instantiated.
#
# When using this connector to interact with the database, all SQL statements are executed using the cursor.

# %%
# create our db cursor object
dbc = db.cursor()

# %% [markdown]
# The cursor allows us to execute all SQL transactions on the database as if we were logged into the server.
#
# If a transaction fetches results from the database (returns a set of records), the connector object will retain the results. This feature can be useful for later use in a more "pythonic" way, integrating our database queries with other Python statements.
#
# The syntax for issuing a generic SQL statement is as follows:
#
# ```python
# connector_object.execute(my_sql_query)
# ```
#
# For example, let's execute the same check as before by asking MySQL to show us all available databases...

# %%
# show all available databases
dbc.execute(
"SHOW DATABASES"
)

# %% [markdown]
# No output is printed because the result of this SQL transaction is collected into the cursor as a list of records (tuples).
#
# To retrieve the results, we can simply loop over them.

# %%
# loop over the container to fetch the results
for _ in dbc:
    print(_)
# Out:
# ('IMDb',)
# ('information_schema',)
# ('my_db',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)

# %% [markdown]
# If we are `root` users in this example, we can access the inner structure of the MySQL server, which already contains a few databases by default.
#
# After fetching the output of the transaction, the cursor reaches "the end" of the records and becomes available to perform a new transaction.

# %%
# use fetch to retrieve one, many, or all entries in the cursor
dbc.fetchone()

#dbc.fetchmany(2)

#dbc.fetchall()

# %% [markdown]
# If one wants to perform a new transaction without collecting the output of the previous one from the cursor, a reset must be issued first:
#
# ```python
# connector_object.reset()
# ```

# %%
dbc.reset()

# %% [markdown]
# If a generic user (i.e., not the `root` user) is logged into the database server, they will not have access to certain functionalities and won't be able to see the previous list of all databases.
#
# Some of these databases and tables are protected and used to store additional information about the state of the MySQL server and the connected users.

# %%
# connecto to the database as a non-root user
udb = mysql.connector.connect(
  user="my_user",
  password="my_pwd",
  host="db",
)

# create a cursor
udbc = udb.cursor()

# execute the transaction
udbc.execute(
"SHOW DATABASES"
)

# fetch all results
udbc.fetchall()
# Out:
# [('information_schema',), ('performance_schema',)]

# %% [markdown]
# #### iPython Magic
#
# Another way to execute queries from Python within a Jupyter Notebook is by utilizing notebook "magic" functions, which are based on iPython and SQLAlchemy.
#
# This approach is similar to loading inline figures from Matplotlib using `%matplotlib inline`.
#
# To instruct iPython to interpret SQL commands and connect to the appropriate database, we need to:
#
# 1. Load the extension for the SQL language.
# 2. Set the environment variable to point to the connection to the database.

# %%
# %load_ext sql

# %env DATABASE_URL=mysql+mysqlconnector://root:root_pwd@db
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# Out:
# env: DATABASE_URL=mysql+mysqlconnector://root:root_pwd@db

# %% [markdown]
# Now, notebook cells can execute SQL transactions directly in plain SQL by starting the cell with `%%sql`.
#
# By default, the result is also printed using the `pretty` format, similar to the pandas-like format.

# %%
# %%sql
#
# SHOW DATABASES;
# Out:
# 6 rows affected.
# [('IMDb',),
#  ('information_schema',),
#  ('my_db',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',)]

# %% [markdown]
# An additional benefit is that a single `%sql` (not a double `%%sql`) can be used to combine a SQL query with any Python command.

# %%
my_python_var = %sql SHOW DATABASES

print(my_python_var)
# Out:
#  * mysql+mysqlconnector://root:***@db
# 6 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# |        IMDb        |
# | information_schema |
# |       my_db        |
# |       mysql        |
# | performance_schema |
# |        sys         |
# +--------------------+

# %% [markdown]
# The combination of either of the two Pythonic methods can be used to easily redirect the output of database transactions to leverage other well-known Python modules, such as plotting with Matplotlib.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist(my_python_var);
plt.xticks(rotation='vertical');

# %% [markdown]
# ## 02 Database and Table creation

# %% [markdown]
# We have already seen how to inspect the server to see which databases are present using the command:
#
# ```mysql
# SHOW DATABASES;
# ```
#
# To start interacting with a specific database, we can select it using `USE`:
#
# ```mysql
# USE <DB_NAME>;
# ```
#
# If the user has been granted the right to access this database, it's possible to start investigating its content.

# %% [markdown]
# If we want to create a new database to work with instead, we can use the command:
#
# ```mysql
# CREATE DATABASE <DB_NAME>;
# ```
#
# A more complex syntax can be used to create a new database only if no other database with the same name already exists:
#
# ```mysql
# CREATE DATABASE IF NOT EXISTS <DB_NAME>;
# ```

# %% [markdown]
# - Check if a DB named `my_db` exists.
# - If not, create one.
# - Then, switch to the new DB to start using it.

# %%
# %%sql
#
# CREATE DATABASE IF NOT EXISTS my_db;
# USE my_db;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# All tables contained in the DB are shown in a similar way to what used to show all DBs on the server:
#
# ```mysql
# SHOW TABLES;
# ```
#
# **NB**: we are inspecting the content of a specific DB (the one selected with `USE <DB_NAME>`)

# %%
# %%sql
#
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('products',)]

# %% [markdown]
# The analogous Pythonic way to execute the same list of commands (using the `mysql.connector` driver) is the following:
#
# **NB**: This time we are not retrieving results from the server, but are instead asking the DBMS to _create_ a new database. We are issuing a request that requires us to **commit** a change in the MySQL server

# %%
# defining the sql command line
sql_ = "CREATE DATABASE IF NOT EXISTS my_db;"

# instructing the cursor to execute it
dbc.execute(sql_)

# in this case the result of the sql transaction is not to return a list of items 
# it is instead a change in the DB structure
# therefore, for the change to have an effect, the change is to be committed to the DB
db.commit()

# %% [markdown]
# All other commands discussed so far (`USE` and `SHOW`), do not require any change to be committed, therefore we can simply issue them via the cursor.
#
# Creating new databases, or changing the structure (_schema_) or the content (_instance_) of a database, will instead require a `commit`.

# %%
# use the my_db database
dbc.execute("USE my_db")

# show all tables
dbc.execute("SHOW TABLES")
dbc.fetchall()
# Out:
# [('products',)]

# %% [markdown]
# So far the `my_db` database is empty, so let's use the same lines presented in the slides to create a dummy `Users` table.
#
# Any table can then be inspected to check its schema by listing all attributes.
#
# 1. Begin by creating a `Users` table. Define the schema by specifying each attribute.
# 2. Verify if it has been successfully created in the database. Use the `SHOW` command for this purpose.
# 3. Inspect the schema of the `Users` table, execute the `DESCRIBE <TABLE_NAME>` command.

# %%
# %%sql
#
# # create a table following the schema on the slides
# CREATE TABLE Users (
#     UserID    varchar(30),
#     BadgeNum  int(16),
#     FirstName varchar(255),
#     LastName  varchar(255),
#     Age       int,
#     OtherAttr float
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # show the tables in the current database
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('Users',), ('products',)]

# %%
# %%sql
#
# # describe the table `Users` -> describes the schema, not the content
# DESCRIBE Users;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 6 rows affected.
# [('UserID', 'varchar(30)', 'YES', '', None, ''),
#  ('BadgeNum', 'int', 'YES', '', None, ''),
#  ('FirstName', 'varchar(255)', 'YES', '', None, ''),
#  ('LastName', 'varchar(255)', 'YES', '', None, ''),
#  ('Age', 'int', 'YES', '', None, ''),
#  ('OtherAttr', 'float', 'YES', '', None, '')]

# %% [markdown]
# Following the previous examples, let's perform the same transactions using the `mysql.connector` driver. Since the `Users` table already exists, we will create a new table called `Users_py`.
#
# Remember the following points:
#
# - Utilize the DB Cursor to execute the transactions.
# - Transactions that change the content of the DB must be _committed_ to the DB.
# - Transactions returning the content of the DB host their results _in the cursor_.

# %%
# create a table following the schema on the slides
sql = 'CREATE TABLE Users_py (\
       UserID    varchar(30),\
       BadgeNum  int(16),\
       FirstName varchar(255),\
       LastName  varchar(255),\
       Age       int,\
       OtherAttr float);'
dbc.execute(sql)
db.commit()

# %%
# show the tables in the current database
dbc.execute("SHOW TABLES")
dbc.fetchall()
# Out:
# [('Users',), ('Users_py',), ('products',)]

# %%
# describe the table `Users_py`
dbc.execute("DESCRIBE Users_py")
dbc.fetchall()
# Out:
# [('UserID', 'varchar(30)', 'YES', '', None, ''),
#  ('BadgeNum', 'int', 'YES', '', None, ''),
#  ('FirstName', 'varchar(255)', 'YES', '', None, ''),
#  ('LastName', 'varchar(255)', 'YES', '', None, ''),
#  ('Age', 'int', 'YES', '', None, ''),
#  ('OtherAttr', 'float', 'YES', '', None, '')]

# %% [markdown]
# ## 03 Declaring constraints and altering tables

# %% [markdown]
# Before moving on, let's clean up all existing tables in our database.
#
# To remove an existing table from the database, you can use the following instruction:
#
# ```mysql
# DROP TABLE IF EXISTS <NAME OF YOUR TABLE>;
# ```
#
# **CAUTION**: Dropping a table deletes all records from that table and severs all connections with other tables based on foreign keys. This action can render the entire database unusable. Be extremely careful when executing this command.

# %%
# %%sql
#
# # drop the table Users -> we are dropping both schema and content
# DROP TABLE IF EXISTS Users;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %% [markdown]
# Let's also drop the `Users_py` table using the Python connector.
# This is once again an action that alters the database, thus we must `commit` it.

# %%
# drop the table Users_py
dbc.execute("DROP TABLE IF EXISTS Users_py")
db.commit()

# %%
# inspect the content of the database
dbc.execute("SHOW TABLES")
dbc.fetchall()
# Out:
# [('products',)]

# %% [markdown]
# Create a new `products` table with the following schema:
#
# | Attribute    | Type    | Extra info | Constraint                |
# |--------------|---------|------------|---------------------------|
# | productID    | Integer |            | NOT NULL AUTO_INCREMENT  |
# | productName  | String  | Max length 30 | DEFAULT ''            |
# | unitPrice    | Float   |            | NOT NULL DEFAULT 99999.99|
# | unitsInStock | Integer | Unsigned   | NOT NULL DEFAULT 0        |
#
#
# The `productID` attribute will be our `PRIMARY KEY`.
#
# This can be declared either inline, or at the end of the table definition:
#
# ```mysql
# productID INT NOT NULL UNIQUE AUTO_INCREMENT PRIMARY KEY
# ```
#
# or
#
# ```mysql
# productID INT NOT NULL UNIQUE AUTO_INCREMENT
# [...]
# PRIMARY KEY (productID)
# ```

# %%
# %%sql
#
# # create the products table
# CREATE TABLE IF NOT EXISTS products (
#          productID    INT          NOT NULL UNIQUE AUTO_INCREMENT PRIMARY KEY,
#          productName  VARCHAR(30)  DEFAULT '' ,
#          unitPrice    FLOAT        NOT NULL DEFAULT 99999.99,
#          unitsInStock INT UNSIGNED NOT NULL DEFAULT 0
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'YES', '', '', ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', '')]

# %% [markdown]
# The table does not contain any constraints, default values, or foreign keys.
#
# The **schema** of a given table can be altered by adding/removing Attributes, as well as by adding constraints.
#
# Let's first add a new attribute to the table:
#
# | Attribute       | Type    | Extra info     | Constraint                |
# |-----------------|---------|----------------|---------------------------|
# | productID       | Integer |                | NOT NULL AUTO_INCREMENT  |
# | productName     | String  | Max length 30  | DEFAULT ''               |
# | unitPrice       | Float   |                | NOT NULL DEFAULT 99999.99|
# | unitsInStock    | Integer | Unsigned       | NOT NULL DEFAULT 0       |
# | **isDiscontinued** | **Bool** |              | NOT NULL                  |
#
#
# To alter the **schema** of a table and create a new column we can act on it with:
#
# ```mysql
# ALTER TABLE <THE TABLE>
# ADD COLUMN <NEW COL> <THE NEW ATTRIBUTE DECLARATION>;
# ```

# %% [markdown]
# #### Alter the `products` table and add the `isDiscontinued` attribute

# %%
# %%sql
#
# # alter the table
# ALTER TABLE products
# ADD COLUMN isDiscontinued BOOL NOT NULL;  #boolean is stored ad tinyint
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'YES', '', '', ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', ''),
#  ('isDiscontinued', 'tinyint(1)', 'NO', '', None, '')]

# %% [markdown]
# The `isDiscontinued` attribute does not contain any meaningful constraint or default value.
# Let's consider `0` as a good default value for this attribute:
#
# | Attribute | Type | Extra info | Constraint |
# | --- | --- | --- |--- |
# | productID   | Integer | | NOT NULL AUTO_INCREMENT |
# | productName | String | Max length 30 | DEFAULT '' |
# | unitPrice   | Float | | NOT NULL DEFAULT 99999.99|
# | unitsInStock | Integer | Unsigned | NOT NULL DEFAULT 0 |
# | isDiscontinued  | Bool | | NOT NULL **DEFAULT 0** |
#
# We can use the same `ALTER TABLE` instruction to do this, and set a new default:
#
# ```mysql
# ALTER TABLE <THE TABLE>
# ALTER <ATTRIBUTE> SET DEFAULT <NEW DEFAULT>;
# ```

# %%
# %%sql
#
# # alter the table
# ALTER TABLE products
# ALTER isDiscontinued SET DEFAULT 0;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'YES', '', '', ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', ''),
#  ('isDiscontinued', 'tinyint(1)', 'NO', '', '0', '')]

# %% [markdown]
# We can also impose `productName` to be not-null by altering the table one final time.
#
# | Attribute | Type | Extra info | Constraint |
# | --- | --- | --- |--- |
# | productID   | Integer | | NOT NULL AUTO_INCREMENT |
# | productName | String | Max length 30 | **NOT NULL** DEFAULT '' |
# | unitPrice   | Float | | NOT NULL DEFAULT 99999.99|
# | unitsInStock | Integer | Unsigned | NOT NULL DEFAULT 0 |
# | isDiscontinued  | Bool | | NOT NULL DEFAULT 0 |
#
#
# In MySQL, this implies modifying the entire attribute, thus the Type will have to be re-stated:
#
# ```mysql
# ALTER TABLE <THE TABLE>
# MODIFY <ATTRIBUTE> <ATTRIBUTE TYPE> <CONSTRAINT>;
# ```

# %%
# %%sql
#
# # alter the table
# ALTER TABLE products
# MODIFY productName VARCHAR(30) NOT NULL;  #this may break consistency
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'NO', '', None, ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', ''),
#  ('isDiscontinued', 'tinyint(1)', 'NO', '', '0', '')]

# %% [markdown]
# Let's now create a `suppliers` table with the following description:
#
# | Attribute | Type | Extra info | Constraint |
# | --- | --- | --- |--- |
# | supplierID   | Integer | | NOT NULL AUTO_INCREMENT |
# | supplierName | String | Max length 30 | NOT NULL DEFAULT "" |
# | countryCode   | Char | Length 3 | NOT NULL |
# | email   | String | Max length 30  | NOT NULL |
#
# `supplierID` is going to act as the table's primary key in this case.

# %%
# %%sql
#
# # create the suppliers table
# CREATE TABLE suppliers (
#     supplierID      INT NOT NULL UNIQUE AUTO_INCREMENT PRIMARY KEY,
#     supplierName    VARCHAR(30) NOT NULL DEFAULT "",
#     countryCode     CHAR(3) NOT NULL,
#     email           VARCHAR(30) NOT NULL
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('supplierID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('supplierName', 'varchar(30)', 'NO', '', '', ''),
#  ('countryCode', 'char(3)', 'NO', '', None, ''),
#  ('email', 'varchar(30)', 'NO', '', None, '')]

# %% [markdown]
# Alter the table to include a default "ITA" for `countryCode`

# %%
# %%sql
#
# # alter the table
# ALTER TABLE suppliers
# ALTER countryCode SET DEFAULT "---";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('supplierID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('supplierName', 'varchar(30)', 'NO', '', '', ''),
#  ('countryCode', 'char(3)', 'NO', '', '---', ''),
#  ('email', 'varchar(30)', 'NO', '', None, '')]

# %% [markdown]
# To establish a relation between the `products` and `suppliers` tables, we have to consider that:
#
# - a supplier can supply multiple products
# - a product can be supplied by multiple suppliers
#
# This is a **many-to-many** relationship, which requires a supporting external table.
#
# In one-to-one or one-to-many relationship a foreign key is sufficient.
#
# To establish a many-to-many relationship between the products and suppliers tables, we create a junction table named `supplier_to_product` with foreign keys referencing the `productID` from the `products` table and the `supplierID` from the `suppliers` table.
#
# Create a new `supplier_to_product` table with the following attributes:
#
# | Attribute | Type | Extra info | Constraint |
# | --- | --- | --- |--- |
# | prodID   | Integer | | NOT NULL |
# | supID    | Integer | | NOT NULL |
#
# The combination of supplierID and productID will be the primary key (unique)

# %%
# %%sql
#
# # create the support table
# CREATE TABLE supplier_to_product (
#     prodID     INT NOT NULL,
#     supID      INT NOT NULL
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %% [markdown]
# Neither `prodID` nor `supID` is a good primary key in this case, as we can have both appearing multiple times in the table.
#
# However, a good primary key for this table is the combination `(prodID,supID)` which is unique, and thus, a good key.
#
# We can alter the table to add the primary key statement:
#
# ```mysql
# ALTER TABLE <TABLE>
# ADD PRIMARY KEY (<ATTRIBUTE 1>, <ATTRIBUTE 2>);
# ```

# %%
# %%sql
#
# # alter the table
# ALTER TABLE supplier_to_product
# ADD PRIMARY KEY (prodID, supID);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE supplier_to_product;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('prodID', 'int', 'NO', 'PRI', None, ''),
#  ('supID', 'int', 'NO', 'PRI', None, '')]

# %% [markdown]
# Finally, we can link the 3 tables together by stating which attributes act as the foreign keys in the `supplier_to_product` table, and to which attributes in the parent tables they refer to.
#
# - `prodID` points to the `productID` attribute of `products` table
# - `supID` points to the `supplierID` attribute of `supplier` table
#
# This translates into:
# - `prodID` is a foreign key for `supplier_to_product`
# - `subID` is a foreign key for `supplier_to_product`
# - the combination `(prodID, supID)` is the primary key of `supplier_to_product`
#
# We can declare an attribute as a foreign key by altering the table:
#
# ```mysql
# ALTER TABLE <TABLE>
# ADD FOREIGN KEY (<ATTRIBUTE IN THIS TABLE>) REFERENCES <OTHER TABLE>(<ATTRIBUTE IN OTHER TABLE>);
# ```

# %%
# %%sql
#
# # alter the table
# ALTER TABLE supplier_to_product
# ADD CONSTRAINT FK_prod
# FOREIGN KEY (prodID) REFERENCES products(productID);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # alter the table
# ALTER TABLE supplier_to_product
# ADD CONSTRAINT FK_sup
# FOREIGN KEY (supID) REFERENCES suppliers(supplierID);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE supplier_to_product;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('prodID', 'int', 'NO', 'PRI', None, ''),
#  ('supID', 'int', 'NO', 'PRI', None, '')]

# %% [markdown]
# ## 04 Inserting Updating and Deleting records

# %% [markdown]
# The tables are currently empty.
# We can inspect their content by performing a simple "read" query using `SELECT`.
# We will discuss later the full syntax of the `SELECT` statement... for the time being, it's important to realize that this command will show the entire content of all columns of the table we are inspecting.
#
# ```mysql
# SELECT * FROM <TABLE>;
# ```
#
# To insert a single record into a table we can proceed in either of the two following ways:
#
# 1. By explicitly specifying the names of the columns when passing the tuple containing the values
# ```mysql
# INSERT INTO <TABLE> (<COLUMN1>, <COLUMN2>, <COLUMN3>, ...)
# VALUES (<VALUE1>, <VALUE2>, <VALUE3>, ...);
# ```
# This will work also in the case attributes with a default value will not be explicitly passed
#
#
# 2. By implicitly using all the columns when passing the tuple containing the values
# ```mysql
# INSERT INTO <TABLE>
# VALUES (<VALUE1>, <VALUE2>, ..., <VALUEn>);
# ```
#
# **NB**: 1. is the usually recommended way to perform a data insertion in SQL, as (pretty much always in coding) **explicit is better than implicit**

# %% [markdown]
# Using the `mysql.connector` we can formulate the same data insertion in a more Pythonic way, e.g. to include this statement programmatically into a loop or a function call:
#
# ```python
# sql_ = "INSERT INTO <TABLE> (<COLUMN1>, <COLUMN2>, <COLUMN3>, ...) VALUES (%s, %s, %s, ...)"
# val_ = (<VALUE1>, <VALUE2>, <VALUE3>, ...)
# db_cursor.execute(sql_, val_)
# db.commit()
# ```
#
# Being an active change to the database instance, remember to commit the insert.

# %% [markdown]
# #### Perform a simple data insertion
#
# - Verify that the product table is actually empty.
# - Insert the following list of products into the `products` table.
# - Check the content of the table after the transaction to verify that both the `AUTO_INCREMENT` key and the default values have been taken into account.
#
# | productName | unitPrice | unitsInStock | isDiscontinued |
# | --- | --- | --- |--- |
# | "Founders Porter" | 4.9 | 12 | 0 |

# %%
# %%sql
#
# # retrieve the content of the table
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # insert records into the table
# INSERT INTO products (productName, unitPrice, unitsInStock)
# VALUES ('Founders Porter',4.9 ,12);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# []

# %%
# %%sql
#
# # retrieve the content of the table
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0)]

# %% [markdown]
# Multi-values insert can be performed in a similar way by separating multiple tuples with a comma:
#
# ```mysql
# INSERT INTO <TABLE> (<COLUMN1>, <COLUMN2>, <COLUMN3>, ...)
# VALUES
# (<VALUE11>, <VALUE12>, <VALUE13>, ...),
# (<VALUE21>, <VALUE22>, <VALUE23>, ...),
# (<VALUE31>, <VALUE32>, <VALUE33>, ...);
# ```
#
#
# The Python-based command is similar to the previous one, but it drops the `execute` in favor of `executemany`, using a list of tuples as values:
#
# ```python
# sql_ = "INSERT INTO <TABLE> (<COLUMN1>, <COLUMN2>, <COLUMN3>, ...) VALUES (%s, %s, %s, ...)"
# val_ = [
#     (<VALUE11>, <VALUE12>, <VALUE13>, ...),
#     (<VALUE21>, <VALUE22>, <VALUE23>, ...),
#     (<VALUE31>, <VALUE32>, <VALUE33>, ...) ]
# db_cursor.executemany(sql_, val_)
# db.commit()
# ```

# %% [markdown]
# Add a few more products to the `product` table:
#
# | productName | unitPrice | unitsInStock | isDiscontinued |
# | --- | --- | --- |--- |
# | "Punk IPA" | 5.2 | 45 |  |
# | "HB Dunkel" | 4.5 | 250 |  |
# | "Forst Xmas " | 8.0 | 2 |  |
# | "Damm Complot " | 3.7 | 120 |  |

# %%
# insert records into the table
sql_ = "INSERT INTO products (productName, unitPrice, unitsInStock) VALUES (%s, %s, %s)"
val_ = [
    ('Punk IPA',     5.2,  45),
    ('HB Dunkel',    4.5, 250),
    ('Forst Xmas',   8.0,   2),
    ('Damm Complot', 3.7, 120)]
dbc.executemany(sql_, val_)
db.commit()
     
dbc.execute("SELECT * FROM products"); 
dbc.fetchall()
# Out:
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0),
#  (4, 'Forst Xmas', 8.0, 2, 0),
#  (5, 'Damm Complot', 3.7, 120, 0)]

# %% [markdown]
# Updating entries is a delicate issue in databases, as we can potentially modify all records associated with a number of conditions. This makes the update operation quite powerful and possibly error-prone if not performed with extreme caution.
#
# ```mysql
# UPDATE <TABLE>
# SET <ATTRIBUTE> = <NEW VALUE>
# WHERE <CONDITION>;
# ```
#
# or
#
# ```python
# sql_ = "UPDATE <TABLE> SET <ATTRIBUTE> = <NEW VALUE> WHERE <CONDITION>"
# db_cursor.execute(sql)
# db.commit()
#
# ```
#
# #### Let's update a single record with a "very explicit" condition statement:
#
# - Assign `isDiscontinued` equal to `1` to the "Forst Xmas" product.
# - Check if the update has taken place.

# %%
# %%sql
#
# # update the content of the table
# UPDATE products
# SET isDiscontinued = 1
# WHERE productName = "Forst Xmas";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# []

# %% [markdown]
# Similarly, deleting entries is quite risky if not done with plenty of caution, as a wrong `WHERE` condition might inadvertently lead to the deletion of a large part of your database records.
#
# Remember, with `DELETE`, we remove entire records (i.e., tuples) from the database, not just the content of the `WHERE` conditional statement.
#
# ```mysql
# DELETE FROM <TABLE>
# WHERE <CONDITION>;
# ```
#
# or
#
# ```python
# sql_ = "DELETE FROM <TABLE> WHERE <CONDITION>"
# db_cursor.execute(sql)
# db.commit()
#
# ```
#
# #### Delete all records under a set of conditions:
#
# - Delete all products whose name begins with 'F' and ends with 's'.
# - Check if the deletion has taken place.

# %%
# %%sql
#
# # delete records from the table
# DELETE FROM products
# WHERE productName LIKE "F%s";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# []

# %%
# %%sql
#
# # retrieve the content of the table
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0),
#  (5, 'Damm Complot', 3.7, 120, 0)]

# %% [markdown]
# #### Populate the `suppliers` table according to the following list
#
# | supplierName | countryCode | email|
# | --- | --- | ---|
# | "A hop in the park" | "USA" | "contactme@ahop.com" |
# | "Allez Hops! Cave à bièr" | "FRA" | "itsme@allezhops.com" |
# | "Wild Hops " | "ITA" | "myemail@wildhops.it" |
# |"Beer Paradise"|"ITA"|"beer@beerparadise.it"|

# %%
# %%sql
#
# # insert records into the table
# INSERT INTO suppliers (supplierName, countryCode, email) VALUES
# ("A hop in the park","USA","contactme@ahop.com"),
# ("Allez Hops! Cave à bièr","FRA","itsme@allezhops.com"),
# ("Wild Hops","ITA","myemail@wildhops.it"),
# ("Beer Paradise","ITA","beer@beerparadise.it");
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# []

# %%
# %%sql
#
# # retrieve the content of the table
# SELECT * FROM suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(1, 'A hop in the park', 'USA', 'contactme@ahop.com'),
#  (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com'),
#  (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it'),
#  (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it')]

# %% [markdown]
# Complete the database with the two additional steps:
#
# - Update the "A hop in the park" email address to "anewemail@ahop.com"
# - Populate the table of connections between products and suppliers
#     - Remember that the `supplier_to_product` table is linked to the other two via the respective Foreign Keys
#
# | supplier | products provided |
# | --- | --- |
# | "A hop in the park" | "Punk IPA", "HB Dunkel" |

# %%
sql_ = "UPDATE suppliers SET email = %s WHERE supplierName LIKE %s;"
val_ = ('anewemail@ahop.com', 'A hop%')
dbc.execute(sql_, val_)
db.commit()
     
dbc.execute("SELECT * FROM suppliers"); 
for _ in dbc:
     print(_)
# Out:
# (1, 'A hop in the park', 'USA', 'anewemail@ahop.com')
# (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com')
# (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it')
# (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it')

# %%
# %%sql
#
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0),
#  (5, 'Damm Complot', 3.7, 120, 0)]

# %%
# %%sql
#
# SELECT * FROM suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com'),
#  (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com'),
#  (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it'),
#  (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it')]

# %%
# %%sql
#
# SELECT * FROM supplier_to_product;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO supplier_to_product
# VALUES
# (2,1),
# (3,1);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM supplier_to_product;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(2, 1), (3, 1)]

# %% [markdown]
# Export the DB you have created into a .sql file, and store it for later use.
#
# 1. Connect to the "server" Docker container using bash
# 2. Dump the database using the `mysqldump` command
# ```bash
# $ mysqldump -u <USER> -p <DB NAME>  >  <FULL/PATH/TO/NEW/DB_DUMP.sql>
# ```
# 3. use the folder `/mapd-workspace/dbs` to store the file, as it's the one currently visible from both in- and outside the container

# %% [markdown]
# ## 04 Basic queries

# %% [markdown]
# The `SELECT` statement allows us to perform queries and retrieve data from a DB.
#
# We can perform queries on a single table in the DB, as well as perform complex queries that span multiple interconnected tables, with one-to-one, one-to-many, and many-to-many relationships across records.
#
# Any `SELECT` statement is composed of at least:
#
# ```sql
# SELECT <TABLE1.ATTRIBUTE1>, <TABLE2.ATTRIBUTE2>   --# the list of attributes to show
#                                                   --# the * wildcard symbol means ALL attributes
#
# FROM <TABLE1>, <TABLE2>                           --# the table, or list of tables
#                                                   --# from which to extract the attributes
#
# WHERE <CONDITIONS>                                --# (optional) condition statement
# ```
#
# The same structure applies to Python-based connectors:
#
# ```python
# db_cursor.execute("""
#     SELECT <TABLE1.ATTRIBUTE1>, <TABLE2.ATTRIBUTE2>
#     FROM <TABLE1>, <TABLE2>
#     WHERE <CONDITIONS>
# """)
# res_ = db_cursor.fetchall()
# for _ in res_:
#     print(_)
# ```
#
# As an alternative, `db_cursor.fetchone()` can be used to print out only one of possibly many records.

# %% [markdown]
# #### Get the email of all suppliers from Italy

# %%
# %%sql
#
# SELECT email
# FROM suppliers
# WHERE countryCode="ITA";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('myemail@wildhops.it',), ('beer@beerparadise.it',)]

# %% [markdown]
# #### Get all information for products with unit price greater than 4

# %%
# %%sql
#
# SELECT *
# FROM products
# WHERE unitPrice>4;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0)]

# %% [markdown]
# #### Select all products with unit cost less than 5, and list them in descending order of units in stock

# %%
# %%sql
#
# SELECT *
# FROM products
# WHERE unitPrice<5
# ORDER BY unitsInStock DESC;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [(3, 'HB Dunkel', 4.5, 250, 0),
#  (5, 'Damm Complot', 3.7, 120, 0),
#  (1, 'Founders Porter', 4.9, 12, 0)]

# %% [markdown]
# **Group by** is a common statement that allows us to perform data aggregation.
#
# If you're familiar with `pandas`, this should not be new to you.
#
# Just remember:
# 1. No group by statement is possible without an aggregation function.
# 2. Group by operations can be quite computationally expensive. In the case of large databases, group by operations might require a long time to execute.

# %% [markdown]
# #### Plot the distribution of suppliers by country

# %%
# %%sql
#
# DESCRIBE suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('supplierID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('supplierName', 'varchar(30)', 'NO', '', '', ''),
#  ('countryCode', 'char(3)', 'NO', '', '---', ''),
#  ('email', 'varchar(30)', 'NO', '', None, '')]

# %%
res_ = %sql SELECT COUNT(countryCode) AS count, countryCode FROM suppliers GROUP BY countryCode;

print (res_);

res_.bar();
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# +-------+-------------+
# | count | countryCode |
# +-------+-------------+
# |   1   |     USA     |
# |   1   |     FRA     |
# |   2   |     ITA     |
# +-------+-------------+

# %% [markdown]
# The main strength of Relational DBs is the possibility of matching information from different tables through **Join** operations.
#
# A join, either performed explicitly or implicitly is:
#
# 1. Computationally expensive. In the case of large databases, join operations might require a long time to execute.
# 2. Very easy to be done wrong, thus resulting in non-meaningful results.
#
# Be sure of which attributes (most often keys) you are performing a join operation on.

# %% [markdown]
# #### Join the `supplier_to_product` table with the `suppliers` table

# %%
# %%sql
#
# SELECT *
# FROM suppliers, supplier_to_product
# WHERE supplier_to_product.supID = suppliers.supplierID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1)]

# %%
# %%sql
#
# SELECT *
# FROM suppliers
# INNER JOIN supplier_to_product ON supplier_to_product.supID = suppliers.supplierID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1)]

# %%
# %%sql
#
# SELECT *
# FROM suppliers
# LEFT JOIN supplier_to_product ON supplier_to_product.supID = suppliers.supplierID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1),
#  (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com', None, None),
#  (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it', None, None),
#  (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it', None, None)]

# %% [markdown]
# "None" is corresponding to "Null" in SQL

# %%
# %%sql
#
# SELECT *
# FROM suppliers
# RIGHT JOIN supplier_to_product ON supplier_to_product.supID = suppliers.supplierID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1)]

# %% [markdown]
# We can concatenate multiple join operations to extract higher-level information out of the connections stored in the database.
#
# #### Add the corresponding product names to the previous join

# %%
# %%sql
#
# SELECT *
# FROM suppliers
# INNER JOIN supplier_to_product ON supplier_to_product.supID = suppliers.supplierID
# INNER JOIN products ON supplier_to_product.prodID = products.productID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1, 2, 'Punk IPA', 5.2, 45, 0),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1, 3, 'HB Dunkel', 4.5, 250, 0)]

# %% [markdown]
# The conjunction of `SELECT`, `GROUP BY`, and `JOIN` statements will allow us to extract non-trivial information out of any Relational database.
#
# #### Add the following records to the `supplier_to_product` table, and perform the following queries:
#
# | supplier | products provided |
# | --- | --- |
# | "Wild Hops" | "Founders Porter", "Punk IPA", "HB Dunkel", "Damm Complot" |
# | "Beer Paradise" | "Punk IPA", "Damm Complot" |
# | "Allez Hops! Cave à bièr" | "Founders Porter", "HB Dunkel" |
#
# 1. show all suppliers of "Damm Complot"
# 2. retrieve the email address of all possible suppliers of "Punk IPA"
# 3. list the unit price of all products supplied by Italian firms, listed in descending order (of unit price)

# %%
sql_ = "INSERT INTO supplier_to_product (prodID, supID) VALUES (%s, %s)"
val_ = [
    # supplier Allez Hops
    (1, 2),
    (3, 2),

    # supplier Wild Hops
    (1, 3),
    (2, 3),
    (3, 3),
    (5, 3),

    # supplier Beer Paradise
    (2, 4),
    (5, 4),
]


dbc.executemany(sql_, val_)
db.commit()
     
dbc.execute("SELECT * FROM supplier_to_product"); 
for _ in dbc:
     print(_)
# Out:
# (2, 1)
# (3, 1)
# (1, 2)
# (3, 2)
# (1, 3)
# (2, 3)
# (3, 3)
# (5, 3)
# (2, 4)
# (5, 4)

# %%
# %%sql
#
# SELECT suppliers.supplierName
# FROM supplier_to_product
# INNER JOIN suppliers ON supplier_to_product.supID = suppliers.supplierID
# INNER JOIN products ON supplier_to_product.prodID = products.productID
# WHERE products.productName = "Punk IPA";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('A hop in the park',), ('Wild Hops',), ('Beer Paradise',)]

# %%
# %%sql
#
# SELECT suppliers.email
# FROM supplier_to_product
# INNER JOIN suppliers ON supplier_to_product.supID = suppliers.supplierID
# INNER JOIN products ON supplier_to_product.prodID = products.productID
# WHERE products.productName = "Punk IPA";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('anewemail@ahop.com',), ('myemail@wildhops.it',), ('beer@beerparadise.it',)]

# %%
# %%sql
#
# SELECT DISTINCT products.unitPrice, products.productName
# FROM supplier_to_product
# INNER JOIN suppliers ON supplier_to_product.supID = suppliers.supplierID
# INNER JOIN products ON supplier_to_product.prodID = products.productID
# WHERE suppliers.countryCode = "ITA"
# ORDER BY unitPrice DESC;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(5.2, 'Punk IPA'),
#  (4.9, 'Founders Porter'),
#  (4.5, 'HB Dunkel'),
#  (3.7, 'Damm Complot')]

# %% [markdown]
# ## 05 Queries on well-formed DBs
#
# In MySQL, we can load entire databases from external files.
#
# The files will contain the full database structure (tables and constraints) and will populate all tables with all records.
#
# To load a database into the MySQL server from the interactive Docker shell, we can simply do the following:
#
# 1. Create a new database named `world`.
# 2. Import the content of the file `/mapd-workspace/dbs/world.sql` into the newly created database via:
#
# ```bash
# $ mysql -u root -p world < /mapd-workspace/dbs/world.sql
# ```
#
# **NB**: The `/mapd-workspace` directory has been defined as a Docker Volume and is a shared location with your computer.

# %%
# %%sql
#
# SHOW DATABASES
# Out:
#  * mysql+mysqlconnector://root:***@db
# 6 rows affected.
# [('IMDb',),
#  ('information_schema',),
#  ('my_db',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',)]

# %% [markdown]
# #### Using the `world` DB, perform queries to answer the following questions.
#
# Additional references can be found here https://dev.mysql.com/doc/world-setup/en/
#
#
# Use a **single query** to answer the questions:
#
# 1. Which country has the largest population?
# 2. Get the total number of cities in Canada.
# 3. Select the country with the most cities.
# 4. List all the languages spoken in the Southeast Asia region.
# 5. Identify the 5 most spoken languages by number of countries.
# 6. What is the total population of the cities in the Caribbean region?
# 7. What Countries have a City named "Kingston"?
# 8. Plot the population density by country, limiting to the 25 with the least density.
# 9. Plot the GNP (Gross Nation Product) of all countries that become independent between 1850 and 1910, limiting to the 10 with the highest GNP.
# 10. Create a scatter plot of the life expectancy vs the GNP of all countries that have Spanish as their Official language.
#
#
# ##### Suggestions:
# - Start by inspecting the database tables' structure
# - When in doubt, check the table content by selecting only a few lines (use `LIMIT` to avoid returning all records)
# - Before finalizing the query, you can always perform "intermediate" queries to check if complex operations (e.g. `GROUP BY` and `JOIN`) are stated correctly

# %%
# %%sql
#
# USE world;
#
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1049 (42000): Unknown database 'world'
# [SQL: USE world;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
#
# DESCRIBE city;
#
# SELECT *
# FROM country
# LIMIT 5
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'my_db.city' doesn't exist
# [SQL: DESCRIBE city;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
#
# DESCRIBE country
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'my_db.country' doesn't exist
# [SQL: DESCRIBE country]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
#
# DESCRIBE city
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'my_db.city' doesn't exist
# [SQL: DESCRIBE city]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
#
# DESCRIBE countrylanguage
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'my_db.countrylanguage' doesn't exist
# [SQL: DESCRIBE countrylanguage]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# #### 1 - Which country has the largest population?

# %%
# %%sql
#
# SELECT   Name, Population
# FROM country
# ORDER BY  Population   DESC
# LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'my_db.country' doesn't exist
# [SQL: SELECT   Name, Population
# FROM country
# ORDER BY  Population   DESC
# LIMIT 1;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
#
# SELECT Name
# FROM country
# WHERE country.Population = (SELECT MAX(Population) FROM country)
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'my_db.country' doesn't exist
# [SQL: SELECT Name
# FROM country
# WHERE country.Population = (SELECT MAX(Population) FROM country)]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# #### 2 - Get the total number of cities in Canada.

# %%
# %%sql
#
# SELECT Code, Name
# FROM country
# WHERE Name = 'Canada'
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'my_db.country' doesn't exist
# [SQL: SELECT Code, Name
# FROM country
# WHERE Name = 'Canada']
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
#
# SELECT COUNT(1) AS CitiesInCanada
# FROM city
# WHERE CountryCode = 'CAN';
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'my_db.city' doesn't exist
# [SQL: SELECT COUNT(1) AS CitiesInCanada
# FROM city
# WHERE CountryCode = 'CAN';]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# #### 3 - Select the country with the most cities.

# %%
# %%sql
#
# SELECT CountryCode, COUNT(1) AS nCities
# FROM city
# GROUP BY CountryCode
# ORDER BY nCities DESC
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'my_db.city' doesn't exist
# [SQL: SELECT CountryCode, COUNT(1) AS nCities
# FROM city
# GROUP BY CountryCode
# ORDER BY nCities DESC
# LIMIT 10;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# #### 4 - List all the languages spoken in the Southeast Asia region.

# %%
# %%sql
#
# #SELECT countrylanguage.Language ###gives duplicates
# SELECT DISTINCT countrylanguage.Language
# FROM countrylanguage
# INNER JOIN  country  ON countrylanguage.CountryCode= country.Code
# WHERE country.Region = 'Southeast Asia'
# # ORDER BY ;
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'my_db.countrylanguage' doesn't exist
# [SQL: #SELECT countrylanguage.Language ###gives duplicates
# SELECT DISTINCT countrylanguage.Language
# FROM countrylanguage
# INNER JOIN  country  ON countrylanguage.CountryCode= country.Code
# WHERE country.Region = 'Southeast Asia'
# # ORDER BY ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# #### 5 - Identify the 5 most spoken languages by number of countries.

# %%
# %%sql
#
# SELECT Language, COUNT(1) AS countcountry   #we are counting rows, so what is inside the count brackets doesn't matter
# FROM countrylanguage
# GROUP BY Language
# ORDER BY countcountry DESC
# LIMIT 5;
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'my_db.countrylanguage' doesn't exist
# [SQL: SELECT Language, COUNT(1) AS countcountry   #we are counting rows, so what is inside the count brackets doesn't matter
# FROM countrylanguage
# GROUP BY Language
# ORDER BY countcountry DESC
# LIMIT 5;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# #### 6 - What is the total population of the cities in the Caribbean region?

# %%
# %%sql
#
# SELECT SUM(city.Population)
# FROM city
# LEFT JOIN country ON city.CountryCode=country.Code
# WHERE country.Region='Caribbean';
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'my_db.city' doesn't exist
# [SQL: SELECT SUM(city.Population)
# FROM city
# LEFT JOIN country ON city.CountryCode=country.Code
# WHERE country.Region='Caribbean';]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
#
# SELECT country.Region, SUM(city.Population)
# FROM city
# LEFT JOIN country ON city.CountryCode=country.Code
# GROUP BY country.Region
# HAVING country.Region='Caribbean';
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'my_db.city' doesn't exist
# [SQL: SELECT country.Region, SUM(city.Population)
# FROM city
# LEFT JOIN country ON city.CountryCode=country.Code
# GROUP BY country.Region
# HAVING country.Region='Caribbean';]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# #### 7 - What Countries have a City named "Kingston"?

# %%
# %%sql
# USE world;
#
# SELECT country.Name, city.Name
# FROM country
# JOIN city ON country.Code=city.CountryCode
# WHERE city.Name LIKE '%Kingston%' ;
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1049 (42000): Unknown database 'world'
# [SQL: USE world;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# #### 8 - Plot the population density by country, limiting to the 25 with the least density.

# %% [markdown]
# The population density is the total `Population` of a country divided by the `SurfaceArea`.
# We can compute this quantity on the fly during a `SELECT` statement and rename it with an `ALIAS` for convenience.

# %%
res_ = %sql SELECT Name, (Population/SurfaceArea) AS Density    FROM  country   ORDER BY  Density      LIMIT 25;

print(res_)

plt.figure(figsize=(16,3))
res_.bar();
plt.xticks(rotation='vertical');
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'my_db.country' doesn't exist
# [SQL: SELECT Name, (Population/SurfaceArea) AS Density FROM country ORDER BY Density LIMIT 25;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 6
#       3 print(res_)
#       5 plt.figure(figsize=(16,3))
# ----> 6 res_.bar();
#       7 plt.xticks(rotation='vertical');
#
# AttributeError: 'NoneType' object has no attribute 'bar'

# %% [markdown]
# #### 9 - Plot the GNP (Gross Nation Product) of all countries that become independent between 1850 and 1910, limiting to the 10 with the highest GNP

# %% [markdown]
# We can use `BETWEEN a AND b` to select only those entries between two extremes;

# %%
res_ = %sql SELECT  Name, GNP  FROM  country   WHERE IndepYear BETWEEN 1850 AND 1910  ORDER BY GNP DESC   LIMIT 10   ;

print(res_)

plt.figure(figsize=(16,3))
res_.bar();
plt.xticks(rotation='vertical');

# %% [markdown]
# #### 10 - Create a scatter plot of the life expectancy vs the GNP of all countries that have Spanish as their Official language

# %%
res_ = %sql SELECT country.LifeExpectancy,  country.GNP, country.Name \
            FROM country \
            RIGHT JOIN  countrylanguage ON  country.Code=countrylanguage.CountryCode \
            WHERE countrylanguage.Language='Spanish' AND countrylanguage.IsOfficial ;

print(res_)

plt.figure(figsize=(8,6))
for _ in res_:
    plt.scatter(_[0],_[1],s=50);
    plt.annotate(_[2], (float(_[0])*1.002,float(_[1])*1.002));
plt.ylabel('GNP')
plt.xlabel('LifeExpectancy')

# %% [markdown]
# ## 06 More on queries

# %% [markdown]
# Let's import a well-structured database, with several tables and relationships, to be used as a sandbox for further exercises on queries.
#
# The database is freely available and is taken from the IMDb (Internet Movie Database) website (https://www.imdb.com/interfaces/), although severely slimmed down.
#
# This database contains several tables with information about movies, TV shows, people involved in the entertainment industry, and more, spanning from the 1890s to recent years.
#
# To simplify the execution of queries, we will work with a slimmed-down version of the entire database, with still plenty of records for us to extract interesting information.
#
# To start working with the IMDb database, we need to import it into our environment. The database `.sql` file should be downloaded from the link on Moodle and copied into the `/mysql/dbs` folder of the GitHub repository so that it will be found in the mounted volume at the location: `/mapd-workspace/dbs/IMDb_pruned.sql`.

# %% [markdown]
# 1. Create a new DB named `IMDb` (CREATE DATABASE IMDb in the notebook)
# 2. Import the content of the file `/mapd-workspace/dbs/IMDb_pruned.sql` into the newly created DB
# (this might take a minute or two...)
# >>> docker exec -it mysql-db-1 bash
# >>>
# >>> bash-5.1# mysql -u root -p IMDb < /mapd-workspace/dbs/IMDb_pruned.sql

# %% [markdown]
# ### Check which tables are available

# %%
# %%sql
#
# CREATE DATABASE IMDb

# %%
# %%sql
#
# SHOW DATABASES
# Out:
#  * mysql+mysqlconnector://root:***@db
# 6 rows affected.
# [('IMDb',),
#  ('information_schema',),
#  ('my_db',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',)]

# %%
# %%sql
#
# USE IMDb;
#
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 7 rows affected.
# [('Directors',),
#  ('Episode_belongs_to',),
#  ('Had_role',),
#  ('Names_',),
#  ('Title_genres',),
#  ('Title_ratings',),
#  ('Titles',)]

# %%
# %%sql
#
# DESCRIBE Directors;
#
# SELECT *
# FROM Directors
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# 10 rows affected.
# [('tt0035423', 'nm0003506'),
#  ('tt0062336', 'nm0749914'),
#  ('tt0062336', 'nm0765384'),
#  ('tt0065188', 'nm0878702'),
#  ('tt0067460', 'nm0091430'),
#  ('tt0081145', 'nm0193303'),
#  ('tt0081721', 'nm0747808'),
#  ('tt0084870', 'nm0210701'),
#  ('tt0086440', 'nm0450627'),
#  ('tt0087305', 'nm0667257')]

# %%
# %%sql
#
# DESCRIBE Had_role;
#
# SELECT *
# FROM Had_role
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# 10 rows affected.
# [('tt0011216', 'nm0290157', 'Soledad'),
#  ('tt0011216', 'nm0869559', 'Miguélan'),
#  ('tt0011216', 'nm0595321', 'Réal'),
#  ('tt0015724', 'nm0844752', 'Bruno'),
#  ('tt0015724', 'nm0869732', 'Sofía'),
#  ('tt0015724', 'nm0194720', 'Rolando Matute'),
#  ('tt0015724', 'nm0650495', 'Salomé'),
#  ('tt0035423', 'nm0000212', 'Kate Mckay'),
#  ('tt0035423', 'nm0413168', 'Leopold'),
#  ('tt0035423', 'nm0000630', 'Stuart Besser')]

# %% [markdown]
# ### Describe the content of table `Names_`

# %%
# %%sql
#
# DESCRIBE Names_;
#
# SELECT *
# FROM Names_
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# 10 rows affected.
# [('nm0000002', 'Lauren Bacall', 1924, 2014),
#  ('nm0000003', 'Brigitte Bardot', 1934, None),
#  ('nm0000005', 'Ingmar Bergman', 1918, 2007),
#  ('nm0000008', 'Marlon Brando', 1924, 2004),
#  ('nm0000013', 'Doris Day', 1922, 2019),
#  ('nm0000014', 'Olivia de Havilland', 1916, 2020),
#  ('nm0000016', 'Georges Delerue', 1925, 1992),
#  ('nm0000017', 'Marlene Dietrich', 1901, 1992),
#  ('nm0000018', 'Kirk Douglas', 1916, 2020),
#  ('nm0000019', 'Federico Fellini', 1920, 1993)]

# %% [markdown]
# ### Study the distribution of the year of birth of all people included in the database
#
# 1. Start by limiting the query to 1000 entries
#     1. Draw a histogram of the year of birth
#     1. Draw a second histogram with the year of birth of the 1000 youngest people in the list

# %%
# 1.A
by = %sql SELECT birth_year FROM Names_;
birth_years = [row.birth_year for row in by]


plt.hist(birth_years, bins=20, color='blue', edgecolor='black')
plt.title('Histogram of Birth Years')
plt.xlabel('Birth Year')
plt.ylabel('Frequency')
plt.show()
# Out:
#  * mysql+mysqlconnector://root:***@db
# 156311 rows affected.

# %%
byy = %sql SELECT birth_year FROM Names_ ORDER BY birth_year DESC LIMIT 1000;
birth_years_young = [row.birth_year for row in byy]
import numpy as np

plt.hist(birth_years_young, bins=15, color='blue', edgecolor='black', range=(2002, 2020))
plt.title('Histogram of Birth Years (Youngest 1000)')
plt.xticks(np.arange(2002,2021, 2))
plt.xlabel('Birth Year')
plt.ylabel('Frequency')
plt.show()
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1000 rows affected.

# %% [markdown]
# 2. Extend the query to all records in the table
#     1. Check for outliers (inspect min and max)
#     2. If any outlier is found, limit the query to a reasonable range (say... at least people born after 1850)
#     3. Draw a new histogram with the year of birth
#     4. Compute the mean and standard deviation of the year of birth

# %%
# %%sql
# # 2.A
# SELECT MAX(birth_year), MIN(birth_year)
# FROM Names_
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(2021, 13)]

# %%
# %%sql
# # 2.B
# SELECT MAX(birth_year), MIN(birth_year)
# FROM Names_
# WHERE (birth_year > 1850)
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(2021, 1870)]

# %%
# 2.C
by = %sql SELECT birth_year FROM Names_ WHERE (birth_year > 1850);
birth_years = [row.birth_year for row in by]


plt.hist(birth_years, bins=20, color='blue', edgecolor='black')
plt.title('Histogram of Birth Years')
plt.xlabel('Birth Year')
plt.ylabel('Frequency')
plt.show()
# Out:
#  * mysql+mysqlconnector://root:***@db
# 156309 rows affected.

# %%
# %%sql
# # 2.D
# SELECT AVG(birth_year), STDDEV(birth_year)
# FROM Names_
# WHERE (birth_year > 1850)
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(Decimal('1965.4513'), 19.99205313179966)]

# %% [markdown]
# ### Movie stats
#
# 1. Plot the number of titles available in the database for each year over the past 25 years.
# 2. List the names of all actors who have portrayed the character Spider-Man in movies, along with the corresponding movie titles.
# 3. List and count the top 10 people who have appeared the most in movies directed by Wes Anderson.

# %%
# %%sql
#
# DESCRIBE Titles;
#
# SELECT *
# FROM Titles
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# 10 rows affected.
# [('tt0011216', 'movie', 'Spanish Fiesta', 2019, 67),
#  ('tt0015724', 'movie', 'Dama de noche', 1993, 102),
#  ('tt0035423', 'movie', 'Kate & Leopold', 2001, 118),
#  ('tt0059325', 'movie', "Born in '45", 1990, 100),
#  ('tt0059900', 'movie', 'Wenn du groß bist, lieber Adam', 1990, 78),
#  ('tt0062336', 'movie', 'The Tango of the Widower and Its Distorting Mirror', 2020, 70),
#  ('tt0063351', 'movie', 'Summer in Narita', 2012, 108),
#  ('tt0065188', 'movie', 'Vojtech, receny sirotek', 1990, 80),
#  ('tt0067460', 'movie', 'My Kingdom for...', 1995, 85),
#  ('tt0068494', 'movie', 'Domo Arigato', 1990, 91)]

# %% [markdown]
# #### 1 - Plot the number of titles available in the database for each year over the past 25 years.

# %%
# %%sql
#
# SELECT title_type, start_year, COUNT(1)
# FROM Titles
# GROUP BY start_year, title_type
# HAVING title_type='movie' AND start_year>1999
# ORDER BY start_year;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 28 rows affected.
# [('movie', 2000, 3541),
#  ('movie', 2001, 3774),
#  ('movie', 2002, 4047),
#  ('movie', 2003, 4467),
#  ('movie', 2004, 5057),
#  ('movie', 2005, 5701),
#  ('movie', 2006, 6344),
#  ('movie', 2007, 6800),
#  ('movie', 2008, 7999),
#  ('movie', 2009, 9176),
#  ('movie', 2010, 10038),
#  ('movie', 2011, 10597),
#  ('movie', 2012, 11425),
#  ('movie', 2013, 12164),
#  ('movie', 2014, 12854),
#  ('movie', 2015, 13216),
#  ('movie', 2016, 13674),
#  ('movie', 2017, 13994),
#  ('movie', 2018, 13884),
#  ('movie', 2019, 13471),
#  ('movie', 2020, 10789),
#  ('movie', 2021, 10839),
#  ('movie', 2022, 2309),
#  ('movie', 2023, 124),
#  ('movie', 2024, 13),
#  ('movie', 2025, 4),
#  ('movie', 2026, 3),
#  ('movie', 2027, 1)]

# %%
moviesdata = %sql SELECT title_type, start_year, COUNT(1) AS movie_count \
                    FROM Titles GROUP BY start_year, title_type \
                    HAVING title_type='movie' AND start_year>1999 \
                    ORDER BY start_year

print(moviesdata)

years = [row.start_year for row in moviesdata]
counts = [row.movie_count for row in moviesdata]


plt.figure(figsize=(12,6))
plt.plot(years, counts, color='red')
plt.title('Number of Movies per Year (Past 25 Years)')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.xticks(years, rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
#  * mysql+mysqlconnector://root:***@db
# 28 rows affected.
# +------------+------------+-------------+
# | title_type | start_year | movie_count |
# +------------+------------+-------------+
# |   movie    |    2000    |     3541    |
# |   movie    |    2001    |     3774    |
# |   movie    |    2002    |     4047    |
# |   movie    |    2003    |     4467    |
# |   movie    |    2004    |     5057    |
# |   movie    |    2005    |     5701    |
# |   movie    |    2006    |     6344    |
# |   movie    |    2007    |     6800    |
# |   movie    |    2008    |     7999    |
# |   movie    |    2009    |     9176    |
# |   movie    |    2010    |    10038    |
# |   movie    |    2011    |    10597    |
# |   movie    |    2012    |    11425    |
# |   movie    |    2013    |    12164    |
# |   movie    |    2014    |    12854    |
# |   movie    |    2015    |    13216    |
# |   movie    |    2016    |    13674    |
# |   movie    |    2017    |    13994    |
# |   movie    |    2018    |    13884    |
# |   movie    |    2019    |    13471    |
# |   movie    |    2020    |    10789    |
# |   movie    |    2021    |    10839    |
# |   movie    |    2022    |     2309    |
# |   movie    |    2023    |     124     |
# |   movie    |    2024    |      13     |
# |   movie    |    2025    |      4      |
# |   movie    |    2026    |      3      |
# |   movie    |    2027    |      1      |
# +------------+------------+-------------+

# %% [markdown]
# #### 2 - List the names of all actors who have portrayed the character Spider-Man in movies, along with the corresponding movie titles.

# %%
# %%sql
#
# SELECT DISTINCT n.name_, t.primary_title, t.start_year
# FROM Had_role r
# INNER JOIN Names_ n ON r.name_id = n.name_id
# INNER JOIN Titles t ON r.title_id = t.title_id
# WHERE role_ LIKE 'Spider_Man' AND t.title_type = 'movie'
# ORDER BY t.start_year;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 8 rows affected.
# [('Tobey Maguire', 'Spider-Man', 2002),
#  ('Tobey Maguire', 'Spider-Man 2', 2004),
#  ('Tobey Maguire', 'Spider-Man 3', 2007),
#  ('Andrew Garfield', 'The Amazing Spider-Man', 2012),
#  ('Andrew Garfield', 'The Amazing Spider-Man 2', 2014),
#  ('Tom Holland', 'Spider-Man: Homecoming', 2017),
#  ('Tom Holland', 'Spider-Man: Far from Home', 2019),
#  ('Tom Holland', 'Spider-Man: No Way Home', 2021)]

# %% [markdown]
# #### 3 - List and count the top 10 people who have appeared the most in movies directed by Wes Anderson.

# %%
# %%sql
# SELECT r.name_id, n.name_, COUNT(1) AS appear
# FROM Directors d
# INNER JOIN Titles t ON d.title_id = t.title_id
# INNER JOIN Had_role r ON d.title_id = r.title_id
# INNER JOIN Names_ n ON r.name_id = n.name_id
# WHERE d.name_id IN (
#     SELECT name_id
#     FROM Names_
#     WHERE name_ = 'Wes Anderson'
# )
# GROUP BY n.name_, r.name_id
# ORDER BY appear DESC
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('nm0000195', 'Bill Murray', 4),
#  ('nm0005562', 'Owen Wilson', 3),
#  ('nm0005403', 'Jason Schwartzman', 3),
#  ('nm0004778', 'Adrien Brody', 3),
#  ('nm0001378', 'Anjelica Huston', 2),
#  ('nm0005561', 'Luke Wilson', 1),
#  ('nm0235684', 'Ned Dowd', 1),
#  ('nm0288800', 'Shea Fowler', 1),
#  ('nm0001025', 'Seymour Cassel', 1),
#  ('nm0931404', 'Olivia Williams', 1)]

# %% [markdown]
# ### Is IMDB only about movies?
# 1. Check the number of different media types contained in the database
# 1. Plot a histogram summarizing the number of titles per media type
# 1. Find the name and rating of the oldest videogame stored in the database

# %% [markdown]
# #### 1 - Check the number of different media types contained in the database

# %%
# %%sql
# SELECT DISTINCT title_type
# FROM Titles;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('movie',), ('tvEpisode',), ('tvSeries',), ('tvMiniSeries',), ('videoGame',)]

# %% [markdown]
# #### 2 - Plot a histogram summarizing the number of titles per media type

# %%
media = %sql SELECT title_type, COUNT(1) AS count FROM Titles GROUP BY title_type

print(media)
mtype = [row.title_type for row in media]
count = [row.count for row in media]

plt.figure(figsize=(12,6))
plt.bar(mtype, count, color='lightblue', edgecolor='black')
plt.title('Number of titles per media type')
plt.xlabel('Media type')
plt.ylabel('Number of titles')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# +--------------+--------+
# |  title_type  | count  |
# +--------------+--------+
# |    movie     | 239353 |
# |  tvEpisode   | 708598 |
# |   tvSeries   | 59424  |
# | tvMiniSeries | 11963  |
# |  videoGame   |  257   |
# +--------------+--------+

# %% [markdown]
# #### 3 - Find the name and rating of the oldest videogame stored in the database

# %%
# %%sql
# SELECT t.title_type, start_year, t.primary_title, r.average_rating
# FROM Titles t
# INNER JOIN Title_ratings r ON t.title_id=r.title_id
# WHERE title_type LIKE"video%"
# ORDER BY start_year
# LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('videoGame', 1990, 'Lord of the Rings', 6.9)]

# %% [markdown]
# ### Identify interesting outliers
#
# 1. List the names of all movies whose titles begin with "The" and have a runtime between 3 and 4 hours.
# 2. What actor had the most roles as 'Self'?
# 3. Identify what TV series had more than 1,000 episodes, and identify in what year it was aired the first- and last-episode

# %% [markdown]
# #### 1 - List the names of all movies whose titles begin with "The" and have a runtime between 3 and 4 hours.

# %%
# %%sql
# SELECT primary_title, runtime_minutes/60 AS runtime_hours
# FROM Titles
# WHERE title_type = 'movie' AND primary_title LIKE 'The%' AND runtime_minutes/60 BETWEEN 3 AND 4
# Out:
#  * mysql+mysqlconnector://root:***@db
# 116 rows affected.
# [('The Beautiful Troublemaker', Decimal('3.9667')),
#  ('The Best Intentions', Decimal('3.0000')),
#  ('The Wonderful, Horrible Life of Leni Riefenstahl', Decimal('3.0500')),
#  ('The Decline of the Century: Testament L.Z.', Decimal('3.3500')),
#  ('The Beginning and the End', Decimal('3.1333')),
#  ('The Barber of Siberia', Decimal('3.0000')),
#  ('The Green Mile', Decimal('3.1500')),
#  ('The Year After Dayton', Decimal('3.4000')),
#  ('The Sleep Room', Decimal('3.2167')),
#  ('The Lord of the Rings: The Return of the King', Decimal('3.3500')),
#  ('The Big House', Decimal('3.3000')),
#  ('The Murder of JFK: A Revisionist History', Decimal('3.0000')),
#  ('The Girl Who Picks Flowers and the Girl Who Kills Insects', Decimal('3.9333')),
#  ('The Dialogues with Solzhenitsyn', Decimal('3.1333')),
#  ('The Black Sheep', Decimal('3.8500')),
#  ('The Charioteer', Decimal('3.0000')),
#  ('The Himmler Project', Decimal('3.0333')),
#  ('The King', Decimal('3.3000')),
#  ('The Legend of Suriyothai', Decimal('3.0833')),
#  ('The Gospel of John', Decimal('3.0000')),
#  ('The Ister', Decimal('3.1500')),
#  ('The Garden', Decimal('3.2667')),
#  ('The Last Pogo Jumps Again', Decimal('3.3333')),
#  ('The Lottery of the Sea', Decimal('3.0000')),
#  ('The Wolf of Wall Street', Decimal('3.0000')),
#  ('The Lehman Trilogy', Decimal('3.7167')),
#  ('The Royal Opera House: Faust', Decimal('3.7500')),
#  ('The Boro: Fight for Identity', Decimal('3.2500')),
#  ('The Cinema of Ozu According to Kiju Yoshida', Decimal('3.0000')),
#  ('The Secret Fighting Arts of America: Expedition Highlights', Decimal('3.2833')),
#  ('The Twilight Zone: A 60th Anniversary Celebration', Decimal('3.0000')),
#  ('The Most Important Film Ever Made: The Making of A One Crow World', Decimal('3.8333')),
#  ('The Grateful Dead Meet-Up 2018', Decimal('3.0000')),
#  ('The Year of the Discovery', Decimal('3.3333')),
#  ('The Uncertain Kingdom', Decimal('3.9167')),
#  ('The Entertainer', Decimal('3.0000')),
#  ('The Baby Doll Night', Decimal('3.0000')),
#  ('The History of Tanks', Decimal('3.5833')),
#  ('The English Organ', Decimal('3.5000')),
#  ('The Last Mission', Decimal('3.1667')),
#  ('The Outcast', Decimal('3.3500')),
#  ('The Irishman', Decimal('3.4833')),
#  ('The House of the Silent Bat', Decimal('3.1000')),
#  ('The Real Thing', Decimal('3.8667')),
#  ('The Unbroken', Decimal('3.3667')),
#  ("The Winter's Tale - Rehearsed Reading", Decimal('3.5000')),
#  ('The Sodomite Deception', Decimal('3.3500')),
#  ('The Challenge of Rudolf Steiner', Decimal('3.3500')),
#  ('The Power Was with Us: Idle No More', Decimal('3.0000')),
#  ('The Electric Paradise', Decimal('3.6667')),
#  ('The Autobiography of Nicolae Ceausescu', Decimal('3.0000')),
#  ('The Wind Blows Where It Will', Decimal('3.0333')),
#  ('The Hamburg Ballet John Neumeier - A Young Choreographers Evening 2021', Decimal('3.9167')),
#  ('The Last Job', Decimal('3.1667')),
#  ('The Jim Breuer Road Journals', Decimal('3.9500')),
#  ('The Truth About The Philadelphia Experiment: Invisibility, Time Travel and Mind Control - The Shocking Truth', Decimal('3.0000')),
#  ('The Money Masters', Decimal('3.5000')),
#  ('The King and the Commissioner', Decimal('3.0500')),
#  ('The Battleships', Decimal('3.4167')),
#  ("The Word Is Love: Jamaica's Michael Manley", Decimal('3.4167')),
#  ('The Fourth Reich', Decimal('3.0500')),
#  ('The Ultimate 2012 Collection: Explore the Mystery of the Mayan Prophecy', Decimal('3.8333')),
#  ('The Turning', Decimal('3.0000')),
#  ('The Last of the Unjust', Decimal('3.6667')),
#  ('The Adventure of Cohollyingwood Black Prince', Decimal('3.0667')),
#  ('The Furious Gods: Making Prometheus', Decimal('3.6667')),
#  ('The Story of Jonah and the Whale (Sort of...)', Decimal('3.9667')),
#  ('The Oscar Nominated Short Films 2013: Documentary', Decimal('3.0000')),
#  ('The Pogo Film Project', Decimal('3.0000')),
#  ("The Gershwin's 'Porgy and Bess'", Decimal('3.0000')),
#  ('The Great Rome 3D', Decimal('3.7333')),
#  ('The Clairvoyant Fortune', Decimal('3.4000')),
#  ('The Gospel of Matthew', Decimal('3.1667')),
#  ('The Art of Seeing', Decimal('3.5833')),
#  ('The Company We Keep', Decimal('3.0000')),
#  ('The Will: If Only There Were No Nuclear Power Plant', Decimal('3.7500')),
#  ('The Oscar Nominated Short Films 2014: Documentary', Decimal('3.0667')),
#  ('The Presidents: From Politics to Power', Decimal('3.8833')),
#  ('The Life & Times of Abdullah the Butcher', Decimal('3.5000')),
#  ('The Insignificance of Being Gwendolen', Decimal('3.7833')),
#  ('The Gospel of Luke', Decimal('3.5833')),
#  ('The Faithful', Decimal('3.0000')),
#  ('The Rake Creatures', Decimal('3.0500')),
#  ('The Master Class Part 2', Decimal('3.1500')),
#  ('The Crucible', Decimal('3.1667')),
#  ('The American Tapes: Tales of Immigration', Decimal('3.7500')),
#  ('The Future of Freedom: An Interview with NSA Whistleblower William Binney', Decimal('3.9167')),
#  ('The Extincts', Decimal('3.3333')),
#  ('The Next Generation Movie', Decimal('3.5000')),
#  ('The Townie', Decimal('3.2833')),
#  ('The Conciousnous Paradigm', Decimal('3.1667')),
#  ('The Age of Czeslaw Milosz', Decimal('3.0667')),
#  ('The Marvel Experience', Decimal('4.0000')),
#  ('The Great Everything & the Nothing', Decimal('3.5833')),
#  ('The Royal Opera House: La Traviata', Decimal('3.4000')),
#  ('The Way of Thorns', Decimal('4.0000')),
#  ('The Nightmare Series Encyclopedia', Decimal('3.5500')),
#  ('The Woman Who Left', Decimal('3.7667')),
#  ('The Chrysanthemum and the Guillotine', Decimal('3.1500')),
#  ('The Wild Pear Tree', Decimal('3.1333')),
#  ('The Corporation Nation Master', Decimal('3.2333')),
#  ('The World Is Ending Tomorrow', Decimal('3.0000')),
#  ('The Witch of Funtinel', Decimal('3.1833')),
#  ('The Royal Opera House: Il trovatore', Decimal('3.0000')),
#  ('The Republic', Decimal('3.5833')),
#  ('The Poet Professor', Decimal('3.1333')),
#  ('The Bastard Sword', Decimal('3.0333')),
#  ('The Wild Frontier', Decimal('3.6500')),
#  ('The Mystery of Godliness: The Sequel', Decimal('3.0833')),
#  ('The Wild World of Eugen Vöhrmann', Decimal('3.0000')),
#  ('The Night of the Ad Eaters 2013', Decimal('3.5000')),
#  ('The British & Irish Lions: Uncovered', Decimal('4.0000')),
#  ('The Fate of Cysalion', Decimal('3.1333')),
#  ('The Minds of Men', Decimal('3.7167')),
#  ('The Bolshoi Ballet: Live from Moscow - Le Corsaire', Decimal('3.5833')),
#  ('The Lord of the Rings - The Appendices Part 1: From Book to Vision', Decimal('3.3333'))]

# %% [markdown]
# #### 2 - What actor had the most roles as 'Self'?

# %%
# %%sql
# SELECT n.name_, COUNT(1) AS counts
# FROM Had_role r
# INNER JOIN Names_ n ON r.name_id = n.name_id
# WHERE role_ ='Self'
# GROUP BY n.name_
# ORDER BY counts DESC
# LIMIT 5
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('Scott Morrison', 3197),
#  ('Tony Abbott', 2763),
#  ('Donald Trump', 2210),
#  ('John Howard', 1162),
#  ('Pauline Hanson', 1099)]

# %% [markdown]
# #### 3 - Identify what TV series had more than 1,000 episodes, and identify in what year it was aired the first episode

# %%
# %%sql
# SELECT e.parent_tv_show_title_id, t.primary_title, t.start_year, COUNT(1) n
# FROM Episode_belongs_to e
# INNER JOIN Titles t ON e.parent_tv_show_title_id= t.title_id
# GROUP BY e.parent_tv_show_title_id, t.primary_title, t.start_year
# HAVING n>1000
# ORDER BY n DESC
# Out:
#  * mysql+mysqlconnector://root:***@db
# 308 rows affected.
# [('tt0270116', 'Charlie Rose', 9884),
#  ('tt0103434', 'Gute Zeiten, schlechte Zeiten', 7455),
#  ('tt0115227', 'Judge Judy', 7282),
#  ('tt0108977', 'Unter uns', 6803),
#  ('tt0106053', 'Late Show with David Letterman', 6691),
#  ('tt0096597', 'Goede tijden, slechte tijden', 6550),
#  ('tt0144724', 'Young Hearts', 6247),
#  ('tt0289801', 'DAS!', 5433),
#  ('tt4816922', "L'invité", 5273),
#  ('tt0498891', 'Volle Kanne', 5111),
#  ('tt0120986', 'Maury', 4983),
#  ('tt0175383', 'Barátok közt', 4760),
#  ('tt1280627', 'The Rachel Maddow Show', 4721),
#  ('tt0108979', 'Verbotene Liebe', 4664),
#  ('tt0103569', 'The Tonight Show with Jay Leno', 4642),
#  ('tt0162076', 'Familie', 4611),
#  ('tt2364308', 'Bom Dia & Cia', 4496),
#  ('tt0112004', 'Hollyoaks', 4367),
#  ('tt1271991', 'AM - Antes del mediodía', 4348),
#  ('tt0446224', 'Jóban rosszban', 4248),
#  ('tt0185819', 'Secret Lives', 4151),
#  ('tt0241383', 'Doctors', 4136),
#  ('tt0115147', 'The Daily Show', 4000),
#  ('tt0103487', 'Marienhof', 3983),
#  ('tt1886049', 'News Watch 9', 3968),
#  ('tt1752508', "The Last Word with Lawrence O'Donnell", 3957),
#  ('tt0423713', 'Plus belle la vie', 3951),
#  ('tt0217211', 'Loose Women', 3888),
#  ('tt0374364', 'Antena 3 noticias', 3885),
#  ('tt0835962', 'Alles was zählt', 3880),
#  ('tt0185065', 'Fox and Friends', 3866),
#  ('tt0098911', 'Shortland Street', 3856),
#  ('tt0383792', 'Informativos Telecinco', 3830),
#  ('tt0159879', 'Howard Stern', 3830),
#  ('tt0479846', 'Storm of Love', 3802),
#  ('tt0167515', 'Access Hollywood', 3748),
#  ('tt0381791', 'Pasapalabra', 3745),
#  ('tt7112704', 'Yeh Rishta Kya Kehlata Hai', 3646),
#  ('tt0419321', 'Los desayunos de TVE', 3645),
#  ('tt0247094', 'Extra with Billy Bush', 3609),
#  ('tt0262152', 'Breakfast', 3530),
#  ('tt0853076', 'Rote Rosen', 3513),
#  ('tt2389428', 'Tinsel', 3457),
#  ('tt0254031', 'I lampsi', 3457),
#  ('tt0492430', 'The Jeremy Kyle Show', 3437),
#  ('tt0463849', 'Zibb', 3424),
#  ('tt0320037', 'Jimmy Kimmel Live!', 3422),
#  ('tt0305056', 'Last Call with Carson Daly', 3408),
#  ('tt0120974', 'The Jerry Springer Show', 3362),
#  ('tt0473428', 'Scandal!', 3336),
#  ('tt0123366', 'The View', 3313),
#  ('tt0379623', 'The Ellen DeGeneres Show', 3297),
#  ('tt8993360', 'Aadade Aadharam', 3296),
#  ('tt1500570', 'Hannity', 3267),
#  ('tt0439389', 'Pierwsza milosc', 3263),
#  ('tt0409629', 'Telefé noticias', 3248),
#  ('tt1708446', 'Taarak Mehta Ka Ooltah Chashmah', 3135),
#  ('tt0177446', 'Hotel Cæsar', 3123),
#  ('tt0313091', 'Kalimera zoi', 3093),
#  ('tt1338457', 'Porta a Porta', 3056),
#  ('tt6558936', 'Lords of the Air', 2997),
#  ('tt4476002', 'Savdhaan India: Crime Alert', 2945),
#  ('tt0149534', 'Thuis', 2927),
#  ('tt0442646', 'Special Report with Bret Baier', 2914),
#  ('tt1111847', 'Dahoam is Dahoam', 2897),
#  ('tt0382449', 'Fox Business Tonight', 2823),
#  ('tt0439344', 'Arrayán', 2807),
#  ('tt0403813', 'Tavis Smiley', 2796),
#  ('tt1084587', 'The Steve Wilkos Show', 2788),
#  ('tt0106052', "Late Night with Conan O'Brien", 2778),
#  ('tt0380086', 'Anderson Cooper 360°', 2775),
#  ('tt0108821', 'Jenny Jones', 2759),
#  ('tt1981471', 'The Five', 2758),
#  ('tt0376378', 'Club Megatrix', 2746),
#  ('tt0463397', 'Corazón de...', 2654),
#  ('tt10692326', 'Giggle and Hoot', 2649),
#  ('tt8483276', '3000 Whys of Blue Cat', 2625),
#  ('tt1178692', "America's Newsroom", 2624),
#  ('tt0391666', 'Morangos com Açúcar', 2611),
#  ('tt0420472', 'Your World w/Neil Cavuto', 2589),
#  ('tt1094354', 'Barwy szczescia', 2567),
#  ('tt0106113', 'Ricki Lake', 2558),
#  ('tt0388586', 'Cheez TV', 2545),
#  ('tt1112587', 'Spangas', 2514),
#  ('tt10405150', 'Mangala Gowri Maduve', 2507),
#  ('tt2163227', 'CBS This Morning', 2499),
#  ('tt1740718', 'The Talk', 2477),
#  ('tt0409628', 'Telefé noticias a las 19', 2452),
#  ('tt0315727', 'The Wright Stuff', 2380),
#  ('tt6238614', 'Tucker Carlson Tonight', 2378),
#  ('tt0827947', 'Rachael Ray', 2375),
#  ('tt1746642', 'Access Daily', 2374),
#  ('tt1144839', 'Alpha Forum', 2369),
#  ('tt1847905', 'El secreto de Puente Viejo', 2290),
#  ('tt0115338', "The Rosie O'Donnell Show", 2283),
#  ('tt1533783', 'Scènes de ménages', 2266),
#  ('tt0108897', 'Politically Incorrect', 2266),
#  ('tt1261356', 'The Wendy Williams Show', 2252),
#  ('tt2103372', 'Child Bride', 2248),
#  ('tt0282291', 'Divorce Court', 2246),
#  ('tt0426701', 'Le grand journal de Canal+', 2246),
#  ('tt0844203', 'The One Show', 2237),
#  ('tt3230032', 'Varney & Company', 2226),
#  ('tt0472642', 'Love in Difficult Times', 2223),
#  ('tt1095213', 'TMZ on TV', 2201),
#  ('tt1863997', 'Saath Nibhana Saathiya', 2183),
#  ('tt0284767', 'The Factor', 2168),
#  ('tt0970821', 'Você na TV!', 2162),
#  ('tt0437729', 'The Late Late Show with Craig Ferguson', 2158),
#  ('tt2604124', 'Our Crazy Family', 2136),
#  ('tt0945531', 'De wereld draait door', 2133),
#  ('tt0179055', 'Vivere', 2130),
#  ('tt3695158', 'Outnumbered', 2120),
#  ('tt3608508', 'Mornings with Maria Bartiromo', 2119),
#  ('tt0972177', 'CNBC Squawk Box', 2118),
#  ('tt1934806', 'Sasural Simar Ka', 2109),
#  ('tt3776548', 'Making Money with Charles Payne', 2078),
#  ('tt0395043', 'La 2 noticias', 2054),
#  ('tt0375435', 'Saber y ganar', 2044),
#  ('tt0799583', 'Phoenix Runde', 2043),
#  ('tt0306364', 'The News on CNBC', 2040),
#  ('tt1973047', 'Dish Nation', 2022),
#  ('tt3184288', 'The Claman Countdown', 2007),
#  ('tt3725872', 'Studio 10', 2001),
#  ('tt4654452', 'Khabarnaak', 1998),
#  ('tt3651112', 'The Evening Edit', 1995),
#  ('tt0192906', 'The Late Late Show with Craig Kilborn', 1983),
#  ('tt0414740', 'Hardball with Chris Matthews', 1981),
#  ('tt12176850', 'Chandralekha', 1971),
#  ('tt12263940', 'Valli', 1961),
#  ('tt0401937', 'Generations', 1957),
#  ('tt0131689', 'Virginie', 1956),
#  ('tt3911870', 'Kumkum Bhagya', 1945),
#  ('tt8306978', 'Pudhcha Paaul', 1941),
#  ('tt1231460', 'Late Night with Jimmy Fallon', 1940),
#  ('tt4087032', 'Good Mythical Morning', 1914),
#  ('tt0299374', 'Richard & Judy', 1913),
#  ('tt0964948', 'Red Eye w/Tom Shillue', 1881),
#  ('tt0419353', 'Niedrig und Kuhnt - Kommissare ermitteln', 1873),
#  ('tt0283783', 'Prince Mackaroo', 1870),
#  ('tt3550730', 'Yeh Hai Mohabbatein', 1868),
#  ('tt0321019', 'Who Wants to Be a Millionaire', 1855),
#  ('tt12229190', 'Kalyana Parisu', 1836),
#  ('tt0278212', 'Kyunki Saas Bhi Kabhi Bahu Thi', 1833),
#  ('tt0298674', 'Lorraine', 1830),
#  ('tt0783392', 'Mike & Mike', 1828),
#  ('tt0484918', 'Ulice', 1818),
#  ('tt1084172', 'Cavuto on Business', 1811),
#  ('tt0972750', 'Worldwide Exchange', 1784),
#  ('tt2231696', 'Home & Family', 1780),
#  ('tt3416422', 'Seven Sharp', 1775),
#  ('tt0375434', 'Saber vivir', 1765),
#  ('tt1542802', 'Bueréré', 1759),
#  ('tt2117503', 'Puoli seitsemän', 1753),
#  ('tt6518878', 'Paul Murray Live', 1730),
#  ('tt0441955', 'Wowowee', 1700),
#  ('tt0283172', 'Bargain Hunt', 1700),
#  ('tt2057880', 'Watch What Happens Live with Andy Cohen', 1696),
#  ('tt0118435', 'Port Charles', 1687),
#  ('tt0407419', 'La mirada crítica', 1677),
#  ('tt5154982', 'Bhabi Ji Ghar Par Hai', 1664),
#  ('tt1341970', 'Kahaani Ghar Ghar Kii', 1659),
#  ('tt0831821', 'Camera Café', 1649),
#  ('tt0192917', 'Passions', 1646),
#  ('tt0386946', 'M jak milosc', 1638),
#  ('tt12618452', 'Kumkuma Puvvu', 1636),
#  ('tt1240986', 'Happening Now', 1635),
#  ('tt2910420', 'Drzavni Posao', 1634),
#  ('tt3444938', 'The Tonight Show Starring Jimmy Fallon', 1618),
#  ('tt1725140', 'Actors Entertainment', 1616),
#  ('tt0361246', 'Thé ou café', 1612),
#  ('tt1014785', 'ESPN First Take', 1600),
#  ('tt6780318', 'Fútbol Total', 1599),
#  ('tt0487185', 'Mad Money w/ Jim Cramer', 1597),
#  ('tt6155146', 'Ang probinsyano', 1569),
#  ('tt0356286', 'On the Record w/ Brit Hume', 1562),
#  ('tt0400998', 'Democracy Now!', 1558),
#  ('tt3244332', 'Shepard Smith Reporting', 1557),
#  ('tt4264964', 'Evening Urgant', 1550),
#  ('tt0401916', 'C.I.D.', 1549),
#  ('tt4493582', 'After the Bell', 1543),
#  ('tt0372101', 'Telecupón', 1541),
#  ('tt1536749', "Let's Make a Deal", 1540),
#  ('tt0385462', 'Samo zycie', 1537),
#  ('tt0460080', 'Buenos días a todos', 1523),
#  ('tt4979804', 'Kennedy Live', 1514),
#  ('tt12229544', 'Kasthuri', 1511),
#  ('tt1637574', 'Conan', 1508),
#  ('tt0185103', 'WWE Raw', 1506),
#  ('tt12546564', 'Maa....Tomay Chara Ghum Ashena', 1506),
#  ('tt0419336', 'Homes Under the Hammer', 1498),
#  ('tt6814630', 'Uttaran', 1496),
#  ('tt3612488', 'The Noite com Danilo Gentili', 1495),
#  ('tt1067263', 'Trailers from Hell', 1476),
#  ('tt2247207', 'Beni Affet', 1456),
#  ('tt1239083', 'Markus Lanz', 1450),
#  ('tt1868745', 'Kumkum: Ek Pyara Sa Bandhan', 1449),
#  ('tt1360087', 'Sled', 1448),
#  ('tt5995634', 'Skip and Shannon: Undisputed', 1442),
#  ('tt1509677', 'Pointless', 1438),
#  ('tt8669448', 'Karuthamuthu', 1429),
#  ('tt2282359', 'Pavitra Rishta', 1425),
#  ('tt0430836', 'The Insider', 1423),
#  ('tt0307800', 'Pardon the Interruption', 1394),
#  ('tt0458254', 'The Colbert Report', 1389),
#  ('tt1500475', 'Woh Rehne Waali Mehlon Ki', 1380),
#  ('tt3644198', 'Good Morning Britain', 1376),
#  ('tt7509964', 'Shakti: Astitva Ke Ehsaas Ki', 1368),
#  ('tt7174218', 'The Beat with Ari Melber', 1367),
#  ('tt0296318', 'Caméra café', 1366),
#  ('tt12153588', 'Thirumathi Selvam', 1360),
#  ('tt12263842', 'Nadhaswaram', 1355),
#  ('tt7915114', 'Udaan', 1354),
#  ('tt0344647', 'Fox Report with Jon Scott', 1346),
#  ('tt12025550', 'No Agenda', 1344),
#  ('tt12263558', 'Vamsam', 1337),
#  ('tt2071236', 'The Chew', 1334),
#  ('tt1450737', 'Kasautii Zindagii Kay', 1331),
#  ('tt0399989', 'Maalaala Mo Kaya', 1329),
#  ('tt12264220', 'Mundhanai Mudichu', 1325),
#  ('tt0205656', 'Leeza', 1325),
#  ('tt2621722', 'F.I.R.', 1321),
#  ('tt1836553', 'Opera Van Java', 1316),
#  ('tt12234310', 'Priyamanaval', 1315),
#  ('tt0303443', 'Causa común', 1309),
#  ('tt0355103', 'Lenßen & Partner', 1308),
#  ('tt3004376', 'The Real', 1300),
#  ('tt12223458', 'Anandham', 1297),
#  ('tt2154843', 'Deniz Yildizi', 1291),
#  ('tt0112044', 'Die Harald Schmidt Show', 1288),
#  ('tt0197153', 'Good Day L.A.', 1287),
#  ('tt1170244', 'Morning Joe', 1278),
#  ('tt2077192', 'Erin Burnett OutFront', 1277),
#  ('tt0403765', 'Gente que busca gente', 1273),
#  ('tt12177504', 'Athipookal', 1272),
#  ('tt6409156', 'Tujhyat Jeev Rangala', 1262),
#  ('tt12263646', 'Ilavarasi', 1261),
#  ('tt3513388', 'Late Night with Seth Meyers', 1258),
#  ('tt6846190', 'The Story with Martha MacCallum', 1254),
#  ('tt3697842', 'The Late Show with Stephen Colbert', 1236),
#  ('tt2732726', 'NHK News 9', 1236),
#  ('tt2876418', 'Auf Streife', 1235),
#  ('tt1927826', 'The Bolt Report', 1235),
#  ('tt0103396', 'Dateline NBC', 1225),
#  ('tt2114006', 'Horror Kung-Fu Theatre', 1220),
#  ('tt2057875', 'Vem vet mest?', 1219),
#  ('tt5733018', 'W11. Wydzial sledczy', 1218),
#  ('tt0122335', 'Al salir de clase', 1207),
#  ('tt6650508', 'Uppum Mulakum', 1204),
#  ('tt1786323', 'Ugunsgreks', 1203),
#  ('tt0168366', 'Pokémon', 1190),
#  ('tt1480165', 'The Project', 1189),
#  ('tt5052884', 'Abhalmaya', 1181),
#  ('tt0227972', 'WWE Smackdown!', 1181),
#  ('tt0437758', 'The Tyra Banks Show', 1178),
#  ('tt0216470', 'Esther', 1174),
#  ('tt3503424', 'Celebrity Page', 1172),
#  ('tt4725926', 'Trish Regan Primetime', 1170),
#  ('tt14177526', 'Avaghachi Sansaar', 1168),
#  ('tt1371000', 'Jôhô Presenter Tokudane!', 1165),
#  ('tt9850232', 'Durva', 1164),
#  ('tt0241097', 'Crónicas marcianas', 1164),
#  ('tt1002838', 'Chelsea Lately', 1163),
#  ('tt5832098', 'Fox and Friends First', 1155),
#  ('tt4209386', 'At This Hour with Kate Bolduan', 1151),
#  ('tt0154063', 'Chiquititas', 1150),
#  ('tt1943174', 'CBS Evening News with Scott Pelley', 1142),
#  ('tt0498878', 'Attack of the Show!', 1140),
#  ('tt0476926', 'Nancy Grace', 1134),
#  ('tt7390596', 'The Ingraham Angle', 1131),
#  ('tt12153158', 'Thamarai', 1128),
#  ('tt17156374', 'Auf Streife - Die Spezialisten', 1127),
#  ('tt7124904', 'Tomorrow Is Ours', 1125),
#  ('tt7406432', 'Fox News @ Night', 1124),
#  ('tt0368553', 'Zlotopolscy', 1120),
#  ('tt1137419', 'The Alan Titchmarsh Show', 1120),
#  ('tt11844982', 'Blind Wave', 1111),
#  ('tt3591138', 'Baal Veer', 1110),
#  ('tt3002456', 'New Day', 1104),
#  ('tt5732540', 'Dlaczego ja?', 1103),
#  ('tt12176658', 'Azhagi', 1102),
#  ('tt12182370', 'Maragatha Veenai', 1101),
#  ('tt0184122', 'Holby City', 1097),
#  ('tt0207274', 'TV total', 1087),
#  ('tt0320858', 'Flog It!', 1083),
#  ('tt0395050', 'Le dessous des cartes', 1076),
#  ('tt0208617', 'Die Fallers - Eine Schwarzwaldfamilie', 1075),
#  ('tt1809909', 'Piers Morgan Live', 1063),
#  ('tt9105386', 'Muddulakshmi', 1058),
#  ('tt7989888', 'Cavuto: Coast to Coast', 1055),
#  ('tt0138968', 'Hollywood Squares', 1051),
#  ('tt0182607', 'Klan', 1050),
#  ('tt0346255', 'Eisenbahn-Romantik', 1044),
#  ('tt0131179', 'Detective Conan', 1044),
#  ('tt8544402', 'De fútbol se habla así', 1039),
#  ('tt0462106', 'Good Morning America Weekend Edition', 1039),
#  ('tt7147670', 'Kundali Bhagya', 1038),
#  ('tt4280606', 'The Late Late Show with James Corden', 1028),
#  ('tt12193758', 'Magal', 1026),
#  ('tt3127306', 'Ordinace v ruzové zahrade 2', 1025),
#  ('tt1591173', 'Che tempo che fa', 1021),
#  ('tt10300616', 'Vanambadi', 1018),
#  ('tt8784468', 'Suhani Si Ek Ladki', 1013),
#  ('tt0388629', 'One Piece', 1011),
#  ('tt6052530', 'Quotidien', 1010),
#  ('tt2538744', 'Ukryta prawda', 1006),
#  ('tt0439401', 'Strictly Come Dancing: It Takes Two', 1004),
#  ('tt0401953', 'Kkusum', 1001)]

# %% [markdown]
# ### It's all about the ratings
#
# 1. Group all movies by decade and plot their overall rating distribution trend. Limit the query to the movies with at least 1000 ratings.
# 2. Plot the average rating of each episode of "Games of Thrones". Group by season and compute the average and standard deviation for each season
# 3. Plot the total number of movies produced per year, divided by genre (Action, Comedy, Drama, Thriller, Fantasy), and the yearly rating average per genre

# %% [markdown]
# #### 1 - Group all movies by decade and plot their overall rating distribution trend. Limit the query to the movies with at least 1000 ratings.

# %%
decade_rating = %sql SELECT FLOOR(t.start_year/10)*10 AS decade, AVG(r.average_rating) AS rating\
                FROM Titles t\
                INNER JOIN Title_ratings r ON t.title_id=r.title_id\
                WHERE t.title_type='movie' AND r.num_votes>999\
                GROUP BY decade\
                ORDER BY decade

print(decade_rating)
decade = [row.decade for row in decade_rating]
rating = [row.rating for row in decade_rating]

plt.figure(figsize=(12,6))
plt.plot(decade, rating, color='lightblue')
plt.title('Overall rating distribution trend over decades')
plt.xlabel('Decade')
plt.ylabel('Rating')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# +--------+-------------------+
# | decade |       rating      |
# +--------+-------------------+
# |  None  | 7.599999904632568 |
# |  1990  | 6.364565547778342 |
# |  2000  | 6.246446215802841 |
# |  2010  | 6.158320506098749 |
# |  2020  | 6.268965520191386 |
# +--------+-------------------+

# %% [markdown]
# #### 2 - Plot the average rating of each episode of "Games of Thrones". Group by season and compute the average and standard deviation for each season.

# %%
got = %sql SELECT t.primary_title, e.episode_number, e.season_number, r.average_rating \
        FROM Episode_belongs_to e \
        INNER JOIN Title_ratings r ON e.episode_title_id=r.title_id \
        INNER JOIN Titles t ON e.episode_title_id=t.title_id \
        WHERE e.parent_tv_show_title_id IN (SELECT title_id \
                                    FROM Titles \
                                    WHERE primary_title='Game of Thrones')\
        ORDER BY e.season_number, e.episode_number

episode = [row.primary_title for row in got]
rating = [row.average_rating for row in got]

plt.figure(figsize=(12,6))
plt.plot(episode, rating, color='blue')
plt.title('Rating GoT episode')
plt.xlabel('Episode')
plt.ylabel('Rating')
plt.xticks(episode,rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
#  * mysql+mysqlconnector://root:***@db
# 73 rows affected.

# %%
# %%sql
# SELECT e.season_number, AVG(r.average_rating) avg_season_rating, STDDEV(r.average_rating) std_season_rating
# FROM Episode_belongs_to e
# INNER JOIN Title_ratings r ON e.episode_title_id=r.title_id
# INNER JOIN Titles t ON e.episode_title_id=t.title_id
# WHERE e.parent_tv_show_title_id IN (SELECT title_id
#                                     FROM Titles
#                                     WHERE primary_title='Game of Thrones')
# GROUP BY e.season_number
# ORDER BY e.season_number
# Out:
#  * mysql+mysqlconnector://root:***@db
# 8 rows affected.
# [(1, 9.100000095367431, 0.279284841851893),
#  (2, 8.960000038146973, 0.3322648385598139),
#  (3, 9.05, 0.3905124105321288),
#  (4, 9.310000038146972, 0.3832752574106418),
#  (5, 8.830000019073486, 0.5273518051323894),
#  (6, 9.05999984741211, 0.588557477116479),
#  (7, 9.099999972752162, 0.37416567313687327),
#  (8, 6.333333412806193, 1.3634107864471021)]

# %% [markdown]
# #### 3 - Plot the total number of movies produced per year, divided by genre (Action, Comedy, Drama, Thriller, Fantasy), and the yearly rating average per genre

# %%
# %%sql
# SELECT t.start_year, g.genre, COUNT(1) AS count, AVG(average_rating) AS average_rating
# FROM Titles t
# INNER JOIN Title_genres g ON t.title_id = g.title_id
# INNER JOIN Title_ratings r ON t.title_id=r.title_id
# WHERE title_type='movie' AND start_year != 'None'
# GROUP BY t.start_year, g.genre
# ORDER BY start_year
# Out:
#  * mysql+mysqlconnector://root:***@db
# 733 rows affected.
# [(1990, 'Action', 385, 5.513246741232934),
#  (1990, 'Adventure', 114, 5.796491223469115),
#  (1990, 'Animation', 25, 6.851999988555908),
#  (1990, 'Biography', 48, 6.672916695475578),
#  (1990, 'Comedy', 550, 5.837272716435519),
#  (1990, 'Crime', 268, 5.82089550548525),
#  (1990, 'Documentary', 130, 7.033076946551983),
#  (1990, 'Drama', 975, 6.179179479770172),
#  (1990, 'Family', 76, 6.0592104949449235),
#  (1990, 'Fantasy', 96, 5.828124990065892),
#  (1990, 'History', 45, 6.693333339691162),
#  (1990, 'Horror', 172, 5.012209293454192),
#  (1990, 'Music', 29, 6.468965513952847),
#  (1990, 'Musical', 26, 6.430769296792837),
#  (1990, 'Mystery', 68, 5.676470588235294),
#  (1990, 'Romance', 204, 5.969117630346148),
#  (1990, 'Sci-Fi', 68, 5.1029411729644325),
#  (1990, 'Sport', 17, 5.847058913286994),
#  (1990, 'Thriller', 189, 5.478306881334416),
#  (1990, 'War', 46, 6.4217391117759375),
#  (1990, 'Western', 10, 5.7799999713897705),
#  (1991, 'Action', 348, 5.474999997122534),
#  (1991, 'Adventure', 116, 5.770689670381875),
#  (1991, 'Animation', 42, 6.509523828824361),
#  (1991, 'Biography', 48, 7.006250023841858),
#  (1991, 'Comedy', 563, 5.90976910142238),
#  (1991, 'Crime', 204, 5.955882354109895),
#  (1991, 'Documentary', 162, 7.118518537945217),
#  (1991, 'Drama', 1016, 6.194586609761546),
#  (1991, 'Family', 60, 6.2800000270207725),
#  (1991, 'Fantasy', 113, 5.744247797316155),
#  (1991, 'History', 47, 6.73829788857318),
#  (1991, 'Horror', 141, 5.069503544070196),
#  (1991, 'Music', 46, 6.478260931761368),
#  (1991, 'Musical', 33, 6.103030255346587),
#  (1991, 'Mystery', 72, 5.6347222361299725),
#  (1991, 'News', 1, 3.0),
#  (1991, 'Romance', 228, 6.111842104217462),
#  (1991, 'Sci-Fi', 69, 5.1014492719069775),
#  (1991, 'Sport', 17, 5.676470546161427),
#  (1991, 'Thriller', 169, 5.39881656579012),
#  (1991, 'War', 44, 6.2886364026503125),
#  (1991, 'Western', 9, 5.9888888994852705),
#  (1992, 'Action', 331, 5.545317216942317),
#  (1992, 'Adventure', 94, 5.826595760406332),
#  (1992, 'Animation', 36, 6.34166665871938),
#  (1992, 'Biography', 43, 6.818604657816333),
#  (1992, 'Comedy', 568, 5.80211268281433),
#  (1992, 'Crime', 228, 5.88552632352762),
#  (1992, 'Documentary', 165, 7.2684848207415955),
#  (1992, 'Drama', 926, 6.215118798014927),
#  (1992, 'Family', 59, 6.028813564171226),
#  (1992, 'Fantasy', 78, 6.0487179695031585),
#  (1992, 'History', 46, 6.956521739130435),
#  (1992, 'Horror', 130, 5.264615393601931),
#  (1992, 'Music', 48, 6.831250016887982),
#  (1992, 'Musical', 27, 6.537037037037037),
#  (1992, 'Mystery', 60, 5.714999995628992),
#  (1992, 'Romance', 249, 6.0722891614140275),
#  (1992, 'Sci-Fi', 48, 5.137500002980232),
#  (1992, 'Sport', 22, 6.3681818355213515),
#  (1992, 'Thriller', 195, 5.538974356039977),
#  (1992, 'War', 39, 6.569230752113538),
#  (1992, 'Western', 9, 6.233333322736952),
#  (1993, 'Action', 338, 5.5254437732978685),
#  (1993, 'Adventure', 91, 5.787912064856226),
#  (1993, 'Animation', 26, 7.211538443198571),
#  (1993, 'Biography', 67, 6.925373137886845),
#  (1993, 'Comedy', 518, 5.822007720534866),
#  (1993, 'Crime', 256, 5.655078110285103),
#  (1993, 'Documentary', 163, 7.211656450493935),
#  (1993, 'Drama', 963, 6.143302177466831),
#  (1993, 'Family', 80, 5.8812499940395355),
#  (1993, 'Fantasy', 86, 5.93604650331098),
#  (1993, 'History', 48, 6.829166650772095),
#  (1993, 'Horror', 112, 5.007142839687211),
#  (1993, 'Music', 41, 7.031707310095066),
#  (1993, 'Musical', 24, 5.949999968210856),
#  (1993, 'Mystery', 67, 5.9388059715726484),
#  (1993, 'Romance', 244, 5.963524599544337),
#  (1993, 'Sci-Fi', 54, 4.988888872994317),
#  (1993, 'Sport', 13, 6.592307750995342),
#  (1993, 'Thriller', 225, 5.401333321465386),
#  (1993, 'War', 35, 6.30857139314924),
#  (1993, 'Western', 9, 5.855555481380886),
#  (1994, 'Action', 332, 5.397891570645642),
#  (1994, 'Adventure', 118, 5.803389828083879),
#  (1994, 'Animation', 32, 6.465625017881393),
#  (1994, 'Biography', 53, 6.854717002724701),
#  (1994, 'Comedy', 597, 5.831993293722271),
#  (1994, 'Crime', 235, 5.786382984607778),
#  (1994, 'Documentary', 210, 7.14428574017116),
#  (1994, 'Drama', 1025, 6.146829273875166),
#  (1994, 'Family', 97, 5.740206189991272),
#  (1994, 'Fantasy', 86, 5.732558139534884),
#  (1994, 'History', 41, 6.570731738718544),
#  (1994, 'Horror', 98, 5.1755101899711455),
#  (1994, 'Music', 37, 6.954054052765305),
#  (1994, 'Musical', 13, 5.81538462638855),
#  (1994, 'Mystery', 76, 5.552631553850676),
#  (1994, 'Romance', 267, 6.032958798640676),
#  (1994, 'Sci-Fi', 51, 4.737254888403649),
#  (1994, 'Short', 1, 6.800000190734863),
#  (1994, 'Sport', 24, 6.241666654745738),
#  (1994, 'Thriller', 225, 5.297333324220445),
#  (1994, 'War', 36, 6.663888931274414),
#  (1994, 'Western', 13, 5.538461556801429),
#  (1995, 'Action', 349, 5.438968480145692),
#  (1995, 'Adventure', 111, 5.86576577779409),
#  (1995, 'Animation', 34, 6.579411724034478),
#  (1995, 'Biography', 64, 6.698437508195639),
#  (1995, 'Comedy', 527, 5.877419359769948),
#  (1995, 'Crime', 223, 5.904484325460254),
#  (1995, 'Documentary', 204, 7.126960783612494),
#  (1995, 'Drama', 1038, 6.11608863807138),
#  (1995, 'Family', 85, 5.94117649863748),
#  (1995, 'Fantasy', 76, 5.964473699268542),
#  (1995, 'History', 43, 6.606976764146672),
#  (1995, 'Horror', 141, 5.056737593725218),
#  (1995, 'Music', 32, 6.893749959766865),
#  (1995, 'Musical', 22, 5.9363636645403774),
#  (1995, 'Mystery', 79, 5.821518988548955),
#  (1995, 'Romance', 290, 5.96103449566611),
#  (1995, 'Sci-Fi', 85, 5.022352933883667),
#  (1995, 'Sport', 12, 6.533333381017049),
#  (1995, 'Thriller', 252, 5.385317475076706),
#  (1995, 'War', 41, 6.65365857612796),
#  (1995, 'Western', 15, 5.873333374659221),
#  (1996, 'Action', 303, 5.374917483565831),
